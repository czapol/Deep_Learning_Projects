# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:31, 1.00MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
int_words
# Out:
# [5239,
#  3082,
#  11,
#  5,
#  194,
#  1,
#  3135,
#  45,
#  58,
#  155,
#  127,
#  741,
#  476,
#  10597,
#  133,
#  0,
#  27820,
#  1,
#  0,
#  102,
#  854,
#  2,
#  0,
#  15070,
#  60739,
#  1,
#  0,
#  150,
#  854,
#  3584,
#  0,
#  194,
#  10,
#  190,
#  58,
#  4,
#  5,
#  10750,
#  214,
#  6,
#  1324,
#  104,
#  454,
#  19,
#  58,
#  2732,
#  362,
#  6,
#  3675,
#  0,
#  708,
#  1,
#  371,
#  26,
#  40,
#  36,
#  53,
#  540,
#  97,
#  11,
#  5,
#  1423,
#  2758,
#  18,
#  567,
#  686,
#  7097,
#  0,
#  247,
#  5239,
#  10,
#  1052,
#  27,
#  0,
#  320,
#  248,
#  47072,
#  2878,
#  792,
#  186,
#  5239,
#  11,
#  5,
#  200,
#  602,
#  10,
#  0,
#  1135,
#  19,
#  2622,
#  25,
#  8990,
#  2,
#  279,
#  31,
#  4157,
#  141,
#  59,
#  25,
#  6444,
#  4189,
#  1,
#  153,
#  32,
#  362,
#  5239,
#  36,
#  1137,
#  6,
#  447,
#  344,
#  1818,
#  19,
#  4867,
#  0,
#  6761,
#  1,
#  7584,
#  1774,
#  566,
#  0,
#  93,
#  0,
#  247,
#  11084,
#  11,
#  51,
#  7097,
#  89,
#  26,
#  270,
#  37,
#  5951,
#  4864,
#  20496,
#  28,
#  54157,
#  41,
#  317,
#  5,
#  25821,
#  527,
#  7584,
#  371,
#  4,
#  258,
#  1,
#  153,
#  25,
#  1206,
#  11,
#  7584,
#  200,
#  1576,
#  2,
#  15207,
#  332,
#  1774,
#  7097,
#  4867,
#  344,
#  764,
#  160,
#  406,
#  5710,
#  756,
#  1,
#  4106,
#  1131,
#  4338,
#  1536,
#  2,
#  567,
#  8119,
#  98,
#  5239,
#  10,
#  51,
#  1408,
#  686,
#  18,
#  153,
#  26,
#  10,
#  155,
#  7097,
#  36,
#  2034,
#  1423,
#  8186,
#  1,
#  153,
#  46,
#  694,
#  6,
#  31,
#  5,
#  4149,
#  246,
#  371,
#  76,
#  948,
#  78,
#  310,
#  30,
#  4787,
#  371,
#  507,
#  139,
#  2313,
#  3557,
#  364,
#  23,
#  1822,
#  6,
#  1904,
#  59,
#  10,
#  36,
#  8431,
#  78,
#  310,
#  5,
#  246,
#  371,
#  507,
#  31,
#  753,
#  78,
#  1733,
#  2,
#  8077,
#  24619,
#  2,
#  275,
#  1693,
#  19,
#  151,
#  1034,
#  95,
#  225,
#  371,
#  17,
#  1814,
#  24,
#  4787,
#  1556,
#  51,
#  8135,
#  1466,
#  24619,
#  2,
#  12795,
#  4,
#  6130,
#  19,
#  4193,
#  21307,
#  2429,
#  39,
#  16472,
#  2,
#  7249,
#  861,
#  1,
#  1193,
#  10212,
#  2514,
#  28,
#  15188,
#  187,
#  2,
#  48,
#  1123,
#  913,
#  6,
#  1049,
#  468,
#  12324,
#  7097,
#  133,
#  0,
#  0,
#  11084,
#  3058,
#  2,
#  12063,
#  734,
#  4787,
#  6616,
#  4,
#  14704,
#  27,
#  450,
#  485,
#  24619,
#  198,
#  295,
#  948,
#  4,
#  20041,
#  20461,
#  1,
#  54202,
#  300,
#  6,
#  24619,
#  20461,
#  16582,
#  0,
#  30954,
#  1,
#  0,
#  93,
#  44,
#  3834,
#  2,
#  56296,
#  2,
#  3814,
#  0,
#  3415,
#  1,
#  0,
#  1781,
#  187,
#  1,
#  0,
#  625,
#  0,
#  13234,
#  1,
#  3,
#  21,
#  90,
#  122,
#  284,
#  25,
#  243,
#  232,
#  6,
#  31,
#  436,
#  26218,
#  1,
#  173,
#  5239,
#  7714,
#  2535,
#  4,
#  29,
#  95,
#  1,
#  289,
#  602,
#  4310,
#  19,
#  0,
#  13234,
#  16582,
#  49,
#  187,
#  117,
#  46,
#  359,
#  19,
#  0,
#  384,
#  242,
#  96,
#  31,
#  5241,
#  34,
#  331,
#  2726,
#  18,
#  0,
#  838,
#  1378,
#  27,
#  32,
#  8770,
#  46,
#  6472,
#  34,
#  3245,
#  0,
#  27820,
#  28,
#  551,
#  42492,
#  39,
#  30,
#  127,
#  56012,
#  435,
#  84,
#  0,
#  64,
#  1,
#  0,
#  102,
#  462,
#  83,
#  2,
#  25,
#  232,
#  18,
#  47,
#  11,
#  26218,
#  1,
#  173,
#  5239,
#  4,
#  0,
#  173,
#  839,
#  0,
#  45,
#  6,
#  89,
#  0,
#  194,
#  6,
#  1015,
#  1043,
#  42,
#  69,
#  4864,
#  17,
#  936,
#  15006,
#  4574,
#  164,
#  4,
#  29,
#  41486,
#  11821,
#  22923,
#  259,
#  1225,
#  61305,
#  3,
#  22,
#  7,
#  16,
#  99,
#  35,
#  628,
#  0,
#  2663,
#  63,
#  371,
#  33,
#  48,
#  75,
#  93,
#  687,
#  14801,
#  4047,
#  28,
#  817,
#  917,
#  11,
#  101,
#  4,
#  11084,
#  2535,
#  362,
#  5,
#  6068,
#  2,
#  662,
#  4,
#  0,
#  63,
#  701,
#  435,
#  40,
#  4223,
#  1290,
#  19,
#  35,
#  10,
#  30,
#  4787,
#  2,
#  94,
#  25,
#  49,
#  29,
#  5228,
#  4,
#  3,
#  22,
#  8,
#  16,
#  4,
#  0,
#  5365,
#  1,
#  0,
#  150,
#  854,
#  468,
#  12324,
#  334,
#  30,
#  17341,
#  2434,
#  200,
#  1293,
#  141,
#  12324,
#  215,
#  37,
#  89,
#  0,
#  247,
#  5239,
#  55,
#  116,
#  7097,
#  38,
#  1206,
#  32,
#  197,
#  11,
#  0,
#  45,
#  181,
#  4787,
#  529,
#  2,
#  12324,
#  11,
#  0,
#  1836,
#  1,
#  1915,
#  5239,
#  41,
#  34,
#  32,
#  228,
#  75,
#  4787,
#  435,
#  733,
#  2399,
#  2,
#  0,
#  194,
#  17,
#  86,
#  1073,
#  11,
#  30,
#  14128,
#  30714,
#  18,
#  0,
#  12125,
#  58927,
#  34,
#  50,
#  2420,
#  616,
#  4,
#  0,
#  150,
#  854,
#  0,
#  45,
#  567,
#  8738,
#  4787,
#  2935,
#  1032,
#  14606,
#  26,
#  10,
#  636,
#  359,
#  19,
#  26,
#  5400,
#  154,
#  191,
#  2935,
#  1032,
#  14606,
#  334,
#  153,
#  10,
#  917,
#  4,
#  3,
#  12,
#  20,
#  7,
#  19,
#  0,
#  194,
#  4787,
#  17,
#  989,
#  11,
#  5,
#  567,
#  1609,
#  26,
#  10,
#  13,
#  32,
#  890,
#  19,
#  47,
#  848,
#  14606,
#  11,
#  0,
#  1836,
#  1,
#  173,
#  4787,
#  208,
#  4,
#  153,
#  10,
#  917,
#  14606,
#  5463,
#  23,
#  0,
#  419,
#  12954,
#  917,
#  10,
#  6887,
#  4,
#  32,
#  139,
#  35,
#  1346,
#  0,
#  2877,
#  1,
#  15188,
#  917,
#  154,
#  99,
#  3467,
#  38,
#  652,
#  445,
#  6,
#  89,
#  2,
#  3135,
#  43,
#  917,
#  11,
#  46,
#  3591,
#  54,
#  11,
#  15422,
#  1555,
#  13,
#  2965,
#  4,
#  44,
#  258,
#  14606,
#  1164,
#  153,
#  35,
#  88,
#  3225,
#  1131,
#  52,
#  38,
#  751,
#  445,
#  6,
#  89,
#  1049,
#  522,
#  2,
#  1793,
#  4,
#  5814,
#  23,
#  1556,
#  1,
#  5128,
#  2,
#  1293,
#  14606,
#  14,
#  2655,
#  1,
#  11084,
#  33,
#  35,
#  88,
#  29643,
#  967,
#  30,
#  1334,
#  518,
#  99,
#  1131,
#  2,
#  308,
#  159,
#  512,
#  0,
#  807,
#  1,
#  43,
#  1258,
#  218,
#  1258,
#  1037,
#  33,
#  1391,
#  0,
#  908,
#  1,
#  741,
#  64,
#  967,
#  4,
#  442,
#  32,
#  73,
#  2913,
#  19,
#  75,
#  3,
#  73,
#  2965,
#  27,
#  0,
#  1258,
#  1,
#  275,
#  1555,
#  159,
#  4325,
#  2521,
#  498,
#  4,
#  727,
#  10665,
#  18918,
#  30,
#  762,
#  246,
#  986,
#  73,
#  31,
#  177,
#  97,
#  6,
#  740,
#  3274,
#  23,
#  913,
#  6,
#  0,
#  362,
#  1,
#  442,
#  14606,
#  14,
#  948,
#  39,
#  2025,
#  222,
#  150,
#  741,
#  476,
#  1818,
#  2,
#  29,
#  2985,
#  39,
#  1022,
#  4,
#  0,
#  854,
#  1,
#  3,
#  12,
#  20,
#  12,
#  4,
#  302,
#  14606,
#  14,
#  602,
#  1,
#  917,
#  10,
#  647,
#  26,
#  17,
#  347,
#  4,
#  5,
#  112,
#  1,
#  311,
#  79,
#  29,
#  3571,
#  2,
#  59,
#  25,
#  6444,
#  4189,
#  1,
#  47,
#  1,
#  29,
#  948,
#  13,
#  50,
#  2158,
#  1591,
#  67,
#  621,
#  2752,
#  26512,
#  14,
#  15797,
#  4,
#  29,
#  0,
#  10491,
#  2,
#  44,
#  199,
#  26512,
#  1460,
#  19,
#  51,
#  636,
#  1045,
#  344,
#  1774,
#  133,
#  0,
#  2581,
#  1,
#  93,
#  917,
#  11,
#  5,
#  244,
#  389,
#  445,
#  4,
#  152,
#  2,
#  0,
#  147,
#  2581,
#  1,
#  371,
#  39,
#  4592,
#  20962,
#  28,
#  9226,
#  4,
#  0,
#  940,
#  1974,
#  1,
#  371,
#  19,
#  0,
#  1131,
#  25,
#  44,
#  1728,
#  35,
#  5225,
#  15797,
#  2,
#  5,
#  143,
#  1,
#  4,
#  33,
#  1131,
#  73,
#  9744,
#  4,
#  5829,
#  1,
#  50558,
#  66,
#  61,
#  26,
#  17,
#  4,
#  43,
#  567,
#  762,
#  6,
#  175,
#  94,
#  13,
#  118,
#  917,
#  684,
#  1145,
#  78,
#  123,
#  507,
#  13098,
#  5572,
#  310,
#  6,
#  369,
#  6,
#  4107,
#  0,
#  1798,
#  6,
#  118,
#  5464,
#  917,
#  2,
#  153,
#  71,
#  38,
#  4,
#  608,
#  183,
#  19,
#  10,
#  608,
#  199,
#  94,
#  184,
#  11,
#  71,
#  6188,
#  9057,
#  11,
#  7208,
#  71,
#  1225,
#  0,
#  34458,
#  1,
#  0,
#  1798,
#  26512,
#  363,
#  88,
#  391,
#  30,
#  4787,
#  35,
#  1045,
#  66,
#  0,
#  2758,
#  43197,
#  2068,
#  29,
#  948,
#  39,
#  2025,
#  24,
#  55,
#  9935,
#  7097,
#  141,
#  4189,
#  1,
#  29,
#  501,
#  25,
#  3235,
#  63,
#  10328,
#  5239,
#  3246,
#  9655,
#  4,
#  3,
#  ...]

# %%
vocab_to_int
# Out:
# {'denison': 40561,
#  'meme': 6976,
#  'bloggers': 28629,
#  'demonization': 58112,
#  'elegans': 30964,
#  'presenters': 29372,
#  'macrobiotics': 40562,
#  'functor': 11968,
#  'confirmation': 8983,
#  'solander': 53721,
#  'fusion': 3746,
#  'idioms': 28630,
#  'dodd': 32814,
#  'ingenious': 23330,
#  'mercader': 53722,
#  'trebia': 50095,
#  'nippur': 30106,
#  'manichaeans': 46117,
#  'isolation': 6667,
#  'ferber': 55228,
#  'hieratic': 53723,
#  'declarative': 25097,
#  'salamis': 23331,
#  'shruti': 50096,
#  'upscale': 27957,
#  'tamer': 40565,
#  'exaggerates': 61664,
#  'rehabilitate': 50097,
#  'agni': 26184,
#  'starships': 42432,
#  'unguarded': 44611,
#  'unwanted': 10571,
#  'harmonic': 5055,
#  'coarser': 50098,
#  'chinguetti': 53724,
#  'hives': 36074,
#  'meine': 30109,
#  'archaeology': 6414,
#  'gurney': 36531,
#  'insufficiency': 42433,
#  'berkowitz': 40563,
#  'oise': 28631,
#  'haikai': 25098,
#  'cohabitation': 27349,
#  'attenuata': 55780,
#  'veered': 40564,
#  'culhwch': 58114,
#  'isometric': 36075,
#  'pound': 5290,
#  'dwell': 17837,
#  'carloman': 28632,
#  'joliot': 47135,
#  'niclas': 50099,
#  'imf': 5056,
#  'adriaan': 47136,
#  'niger': 8889,
#  'leblanc': 34947,
#  'conception': 4543,
#  'mourn': 40566,
#  'marischal': 34948,
#  'rte': 40567,
#  'tipping': 22116,
#  'drabble': 38934,
#  'foods': 4423,
#  'twister': 44612,
#  'geometry': 2736,
#  'aguilera': 37439,
#  'katal': 44613,
#  'ip': 2885,
#  'daft': 53726,
#  'facile': 53727,
#  'femininity': 40568,
#  'reissues': 44614,
#  'heir': 4658,
#  'storm': 3826,
#  'reunify': 50100,
#  'tanks': 4955,
#  'pacifistic': 61766,
#  'neighborhoods': 8087,
#  'tisdall': 45612,
#  'telstra': 40569,
#  'atlanteans': 47137,
#  'milo': 11497,
#  'esk': 34950,
#  'subgroups': 13476,
#  'cancer': 2352,
#  'sae': 33800,
#  'geeks': 17838,
#  'vulva': 37442,
#  'lithe': 58115,
#  'superstructure': 31892,
#  'attendance': 6012,
#  'sociological': 12845,
#  'valves': 9551,
#  'hamdan': 58116,
#  'piccard': 37431,
#  'temperamental': 50101,
#  'bough': 38826,
#  'contradicting': 23332,
#  'tabulate': 47138,
#  'unlike': 1320,
#  'mencken': 37432,
#  'mmol': 32815,
#  'transsexual': 20027,
#  'pastures': 11969,
#  'northeastern': 7513,
#  'reliquary': 58117,
#  'lesbos': 28633,
#  'bore': 6187,
#  'goddamn': 58118,
#  'poetically': 36923,
#  'pipelines': 12372,
#  'confessional': 21799,
#  'greensboro': 38936,
#  'degas': 36076,
#  'elongated': 15347,
#  'reindeer': 27351,
#  'tsr': 22514,
#  'jammed': 38937,
#  'sections': 2623,
#  'woodlands': 29174,
#  'clicked': 44615,
#  'balhae': 53728,
#  'birthday': 4521,
#  'falk': 32816,
#  'columbus': 2895,
#  'presa': 58120,
#  'esper': 53729,
#  'diminution': 38939,
#  'bagpipe': 20564,
#  'knightly': 44616,
#  'possibilities': 6878,
#  'sindarin': 50102,
#  'highbury': 31907,
#  'salamanca': 27352,
#  'hunnic': 53731,
#  'irrigate': 58121,
#  'trills': 50103,
#  'winkler': 50104,
#  'treading': 50105,
#  'superimposed': 18274,
#  'uplifted': 34951,
#  'meatball': 44617,
#  'electrolyte': 17194,
#  'kanner': 58122,
#  'nguema': 32827,
#  'mcconnell': 47139,
#  'satisfy': 7609,
#  'fabricated': 16820,
#  'overcrowding': 33801,
#  'doctors': 4401,
#  'oscillating': 21472,
#  'bayes': 26752,
#  'pulaski': 37433,
#  'paraclete': 50106,
#  'skenderbeg': 58123,
#  'tapioca': 23910,
#  'farad': 27362,
#  'segue': 50107,
#  'oprah': 33802,
#  'success': 781,
#  'carrots': 30966,
#  'bankruptcies': 42434,
#  'mares': 25380,
#  'galactose': 31894,
#  'awakening': 11815,
#  'pair': 2419,
#  'trs': 26753,
#  'neustadt': 37434,
#  'wernher': 50802,
#  'locator': 26754,
#  'schell': 40570,
#  'viceroys': 47140,
#  'eberhard': 28741,
#  'nanosystems': 40571,
#  'locrian': 47142,
#  'hutchence': 29373,
#  'barbizon': 52877,
#  'hogs': 30110,
#  'applicable': 8117,
#  'playboys': 44619,
#  'microcontrollers': 28634,
#  'zeros': 15200,
#  'spousal': 45225,
#  'civil': 462,
#  'unwashed': 58124,
#  'hexer': 31895,
#  'algerian': 12090,
#  'panicked': 42436,
#  'server': 1848,
#  'theodor': 11149,
#  'emanated': 28635,
#  'offside': 34952,
#  'poseidon': 13141,
#  'mekhilta': 53735,
#  'argent': 28636,
#  'hydrate': 42438,
#  'condoleezza': 38940,
#  'close': 689,
#  'mathworld': 20569,
#  'uyghur': 58125,
#  'haines': 30111,
#  'abatis': 49911,
#  'inductor': 19228,
#  'glyphs': 17839,
#  'privatisation': 17840,
#  'waitress': 25636,
#  'serendip': 58126,
#  'shehu': 58127,
#  'novelists': 9033,
#  'moorcock': 16455,
#  'discogs': 43885,
#  'radiology': 34954,
#  'thirst': 22041,
#  'anatolia': 9711,
#  'punic': 14162,
#  'behe': 16109,
#  'charlemagne': 5419,
#  'strictly': 3494,
#  'wdc': 53736,
#  'mahjong': 8344,
#  'transducer': 42439,
#  'employer': 10088,
#  'upheld': 12550,
#  'slider': 31896,
#  'ascribing': 53737,
#  'bergen': 14022,
#  'crystallography': 19477,
#  'catastrophism': 47144,
#  'bias': 5135,
#  'adaptable': 26755,
#  'snout': 37435,
#  'flavin': 60948,
#  'scrabble': 30967,
#  'bioengineering': 61769,
#  'hiiumaa': 58128,
#  'emancipation': 9034,
#  'kilmer': 28637,
#  'tuscan': 16632,
#  'milah': 23388,
#  'wchl': 58129,
#  'misleading': 9035,
#  'synchronized': 15644,
#  'ipl': 50108,
#  'lambda': 4845,
#  'hammers': 23333,
#  'aa': 5620,
#  'infect': 15067,
#  'rosy': 30112,
#  'contradicts': 19222,
#  'banking': 4690,
#  'guilty': 4464,
#  'mongo': 32817,
#  'maxis': 54006,
#  'resent': 34955,
#  'rust': 13258,
#  'mc': 9247,
#  'ultrasonography': 57638,
#  'seaboard': 23334,
#  'indications': 15201,
#  'kart': 7841,
#  'totient': 53739,
#  'listener': 14499,
#  'memes': 9552,
#  'mangrove': 30113,
#  'born': 266,
#  'poems': 2874,
#  'sucking': 28638,
#  'vents': 27354,
#  'euwe': 53740,
#  'shadow': 4535,
#  'neutron': 8118,
#  'replication': 7772,
#  'judah': 4392,
#  'coaling': 53741,
#  'paramilitary': 11221,
#  'un': 1557,
#  'battersby': 58131,
#  'fiberglass': 31897,
#  'fleischer': 37436,
#  'theron': 24172,
#  'tillich': 45322,
#  'presses': 13042,
#  'drukqs': 51909,
#  'pleasures': 17412,
#  'detour': 28639,
#  'displacement': 8763,
#  'notebooks': 17008,
#  'urdu': 12177,
#  'ingestion': 15813,
#  'sock': 27958,
#  'feathers': 12062,
#  'simms': 49565,
#  'ingersoll': 44622,
#  'vanishing': 22901,
#  'julio': 15068,
#  'batavian': 29374,
#  'cartographers': 25100,
#  'reticularis': 54454,
#  'claim': 848,
#  'verba': 50110,
#  'connes': 53742,
#  'fadh': 38942,
#  'nucleophile': 50111,
#  'claw': 19750,
#  'breakbeats': 42443,
#  'dwarfed': 44623,
#  'oceanic': 12551,
#  'lycopene': 29375,
#  'tools': 2200,
#  'alfaro': 42444,
#  'ai': 4209,
#  'nibble': 37437,
#  'irritability': 32820,
#  'tua': 42445,
#  'amniocentesis': 53743,
#  'willing': 5006,
#  'prescott': 19223,
#  'literals': 36112,
#  'assassination': 3142,
#  'pulleys': 36078,
#  'dweller': 47149,
#  'recognisable': 22155,
#  'pits': 14259,
#  'jelly': 15069,
#  'tha': 25101,
#  'cash': 3208,
#  'suspicion': 10149,
#  'labeled': 6692,
#  'horseshoes': 29376,
#  'flipping': 26198,
#  'bcp': 21466,
#  'preposition': 18090,
#  'babur': 17009,
#  'coup': 2478,
#  'locksmithing': 38943,
#  'sonoma': 53744,
#  'feasible': 12137,
#  'kardashev': 53745,
#  'phallus': 38944,
#  'didi': 50113,
#  'greco': 11644,
#  'enceladus': 58134,
#  'biennial': 34956,
#  'winchester': 12023,
#  'brazen': 47151,
#  'prerecorded': 39191,
#  'powerboat': 58136,
#  'contributions': 3167,
#  'istv': 40572,
#  'nuremberg': 8321,
#  'wronged': 38945,
#  'atrophy': 28640,
#  'ashore': 18578,
#  'cavity': 9304,
#  'rohmer': 30968,
#  'synching': 58137,
#  'carcasses': 47153,
#  'feyerabend': 38946,
#  'dyess': 42446,
#  'christianum': 47154,
#  'layouts': 17626,
#  'esa': 7000,
#  'extremist': 19751,
#  'enlightened': 13059,
#  'zhongzheng': 58138,
#  'spice': 9771,
#  'wba': 58139,
#  'mediation': 8678,
#  'joffe': 57695,
#  'weapons': 1298,
#  'rico': 8174,
#  'deconstructionist': 47243,
#  'serine': 33803,
#  'bombed': 12972,
#  'autism': 7697,
#  'macromolecule': 41799,
#  'tsiolkovsky': 32821,
#  'tolerable': 38947,
#  'azerbaijani': 31898,
#  'critics': 1296,
#  'supersymmetric': 38941,
#  'bunsen': 24623,
#  'unfinished': 8764,
#  'ijcai': 58141,
#  'meaning': 510,
#  'among': 227,
#  'fergana': 47252,
#  'packers': 11816,
#  'nijhoff': 50116,
#  'hydrodynamic': 44624,
#  'textes': 50117,
#  'chr': 12452,
#  'leng': 58142,
#  'isometries': 58143,
#  'deathscythe': 58144,
#  'sudbury': 31899,
#  'blatantly': 30969,
#  'ramstein': 58145,
#  'dinoflagellates': 44625,
#  'gigante': 44712,
#  'objecting': 42448,
#  'loon': 30114,
#  'gateways': 24625,
#  'incidence': 10270,
#  'tantalum': 50723,
#  'tevet': 58146,
#  'oswald': 4830,
#  'guaranteeing': 22136,
#  'logging': 14622,
#  'icy': 22515,
#  'waited': 18035,
#  'halevi': 58147,
#  'equator': 6378,
#  'epistemological': 17010,
#  'lien': 21794,
#  'tempel': 54457,
#  'bolsheviks': 8849,
#  'courtesy': 10500,
#  'bacall': 23737,
#  'infante': 26186,
#  'calhoun': 22892,
#  'conversions': 14623,
#  'tidak': 58148,
#  'ewell': 31900,
#  'phillip': 9216,
#  'enrich': 27355,
#  'picardy': 40573,
#  'always': 521,
#  'terraces': 25637,
#  'artefacts': 23738,
#  'slender': 19224,
#  'fetch': 18966,
#  'included': 511,
#  'before': 151,
#  'servilius': 58151,
#  'accidents': 8482,
#  'kirlian': 31418,
#  'markings': 12787,
#  'tweed': 19225,
#  'ecclesiastical': 6263,
#  'hittites': 16266,
#  'offenbach': 44626,
#  'graphite': 9724,
#  'entangled': 21795,
#  'sentenced': 6526,
#  'reunions': 38948,
#  'fraught': 24626,
#  'clara': 12077,
#  'turbidity': 58152,
#  'os': 1716,
#  'mcfarland': 36958,
#  'veal': 47156,
#  'carbonated': 23335,
#  'maradona': 14163,
#  'andes': 9442,
#  'exponentiation': 22156,
#  'ream': 58153,
#  'garry': 14624,
#  'hare': 12453,
#  'rumble': 38949,
#  'interfacing': 34957,
#  'velde': 47157,
#  'september': 534,
#  'extremes': 8040,
#  'preparations': 9825,
#  'elf': 7890,
#  'organizing': 8148,
#  'lerner': 18498,
#  'copy': 2731,
#  'privateers': 27356,
#  'slain': 11280,
#  'placidia': 38950,
#  'patent': 3068,
#  'tsonga': 52391,
#  'pritchard': 47158,
#  'restrictions': 3319,
#  'sovereigns': 26265,
#  'macc': 53746,
#  'unmaking': 50118,
#  'emulates': 34277,
#  'unbearable': 40574,
#  'hafez': 37440,
#  'lamborghini': 20565,
#  'cariou': 58155,
#  'inari': 58156,
#  'gdb': 21148,
#  'peloponnese': 30115,
#  'gabby': 50119,
#  'vigilance': 41521,
#  'buxtehude': 50120,
#  'whereupon': 16821,
#  'videos': 5985,
#  'formal': 1321,
#  'singular': 3648,
#  'coinciding': 30970,
#  'kach': 23739,
#  'houteff': 58157,
#  'metallica': 6470,
#  'domme': 58158,
#  'pulse': 10042,
#  'hippolytus': 23740,
#  'saunders': 16456,
#  'federals': 50121,
#  'patrons': 15945,
#  'correspondance': 36079,
#  'stringer': 53747,
#  'sampa': 34949,
#  'sociologists': 20205,
#  'fairey': 42450,
#  'stuttgart': 13794,
#  'fsln': 44628,
#  'mccaffrey': 53748,
#  'switzerland': 2762,
#  'histones': 23336,
#  'after': 60,
#  'noone': 58159,
#  'happiness': 7670,
#  'magazines': 5231,
#  'galbraith': 38951,
#  'mundus': 53749,
#  'algerians': 32823,
#  'emotions': 7842,
#  'biome': 22516,
#  'synthetically': 31902,
#  'sans': 15070,
#  'inh': 53750,
#  'narrowband': 50122,
#  'tt': 12060,
#  'sangre': 53751,
#  'delft': 19495,
#  'contempt': 10712,
#  'battlegroup': 58962,
#  'navigator': 9929,
#  'nozick': 31903,
#  'key': 661,
#  'scuba': 21149,
#  'topeka': 30116,
#  'alumina': 25638,
#  'datagram': 22662,
#  'electoral': 3262,
#  'dps': 35283,
#  'akron': 29377,
#  'aztecs': 19496,
#  'expected': 1496,
#  'mathworks': 58027,
#  'tucson': 25103,
#  'thoroughfare': 42451,
#  'billboard': 8342,
#  'scythians': 21467,
#  'delia': 31904,
#  'saurischia': 59860,
#  'eg': 6668,
#  'thc': 42453,
#  'dartford': 50123,
#  'heng': 50124,
#  'randomly': 11065,
#  'quesnay': 58160,
#  'communicative': 23765,
#  'rajputs': 33627,
#  'gunmen': 29379,
#  'aversion': 24173,
#  'alternately': 14024,
#  'perpetually': 26188,
#  'pimp': 30971,
#  'dusting': 42454,
#  'puppet': 10572,
#  'sporting': 6977,
#  'anthem': 4712,
#  'yokoi': 40576,
#  'levelling': 44629,
#  'suburbs': 5367,
#  'internationalist': 37444,
#  'subcultural': 47160,
#  'balloons': 12066,
#  'sinfield': 53753,
#  'phagocytic': 53754,
#  'odr': 58161,
#  'iterations': 22157,
#  'sayer': 34958,
#  'emulate': 13260,
#  'eyewitness': 17627,
#  'bhumi': 36080,
#  'duras': 50125,
#  'riverfront': 30972,
#  'classically': 15946,
#  'butyrate': 58162,
#  'minotaur': 15814,
#  'glaukos': 42455,
#  'infidelity': 28967,
#  'cooke': 19497,
#  'irrevocable': 53755,
#  'porto': 14625,
#  'daemons': 44869,
#  'bauhaus': 15202,
#  'peas': 24174,
#  'chainsaw': 36152,
#  'sue': 8199,
#  'vandals': 12183,
#  'installs': 30973,
#  'louvain': 44631,
#  'parkinson': 15348,
#  'lagopus': 58163,
#  'hathor': 44632,
#  'cnes': 60536,
#  'mennonite': 10207,
#  'isotherm': 55186,
#  'easter': 4093,
#  'lift': 5948,
#  'contravariant': 25639,
#  'pubs': 16457,
#  'kalmyk': 50127,
#  'secretarial': 53757,
#  'sharpest': 51306,
#  'almoravides': 40577,
#  'organism': 4358,
#  'mycoplasma': 42456,
#  'complexity': 2723,
#  'healy': 27959,
#  'discerned': 29417,
#  'umberto': 21796,
#  'hrerbunker': 53758,
#  'commands': 4613,
#  'gyi': 53759,
#  'dnia': 32824,
#  'metallurgy': 15815,
#  'lint': 34959,
#  'away': 725,
#  'sowing': 24627,
#  'jass': 36332,
#  'bookrags': 47162,
#  'capricornus': 42457,
#  'climatology': 36081,
#  'caprice': 50128,
#  'aspire': 21797,
#  'chorale': 21798,
#  'associates': 6715,
#  'massacred': 17841,
#  'velarized': 44633,
#  'untie': 58164,
#  'windmill': 25104,
#  'diglossia': 42459,
#  'unproved': 53760,
#  'sensible': 18275,
#  'vitro': 16575,
#  'ampicillin': 50129,
#  'fossati': 50130,
#  'capitalize': 20566,
#  'fresh': 3665,
#  'theresia': 58165,
#  'tireless': 37315,
#  'one': 3,
#  'chromatography': 13902,
#  'solidity': 51913,
#  'arrival': 3807,
#  'airways': 7040,
#  'tubman': 58166,
#  'iia': 25105,
#  'picchi': 44634,
#  'punta': 42460,
#  'categories': 2602,
#  'hermes': 9305,
#  'belo': 30117,
#  'whorehouse': 58167,
#  'survivability': 38955,
#  'reasoner': 47163,
#  'flattery': 44635,
#  'wrap': 20028,
#  'apion': 50131,
#  'bantu': 7808,
#  'everything': 2103,
#  'commandant': 21469,
#  'kirkham': 58168,
#  'crompton': 53762,
#  'bakersfield': 29380,
#  'newswire': 50132,
#  'ferry': 6693,
#  'maliki': 44636,
#  'include': 211,
#  'protectionism': 26757,
#  'havre': 29381,
#  'praia': 28690,
#  'locations': 3074,
#  'ic': 9772,
#  'transcontinental': 13142,
#  'unwise': 33804,
#  'raise': 3864,
#  'cretans': 30974,
#  'hectares': 33805,
#  'neely': 46423,
#  'causing': 2316,
#  'esophagus': 38956,
#  'django': 16633,
#  'bunghole': 58169,
#  'sumitomo': 53763,
#  'perez': 21150,
#  'haunting': 23337,
#  'mortification': 50134,
#  'microtubules': 13903,
#  'liebig': 26758,
#  'stale': 30975,
#  'pliers': 58170,
#  'wave': 1902,
#  'compactness': 24628,
#  'inc': 2369,
#  'nihilistic': 34960,
#  'weymouth': 44637,
#  'noteworthy': 9443,
#  'kazakstan': 24203,
#  'annob': 53764,
#  'gracchi': 58172,
#  'fs': 26376,
#  'metaplot': 58173,
#  'wends': 40578,
#  'matthews': 17260,
#  'optimum': 14920,
#  'bytecode': 22893,
#  'uart': 47165,
#  'inconvenient': 27960,
#  'gh': 17842,
#  'verb': 2700,
#  'inferential': 36082,
#  'ff': 6669,
#  'bleak': 19752,
#  'mourners': 28642,
#  'cale': 42462,
#  'additionally': 2963,
#  'microarray': 58175,
#  'debunked': 30965,
#  'flocks': 26104,
#  'comp': 12552,
#  'rearranged': 23338,
#  'utterances': 25640,
#  'tract': 8258,
#  'karpov': 10989,
#  'garuda': 44638,
#  'municipal': 4571,
#  'ambulatory': 37447,
#  'scot': 32825,
#  'xxx': 21151,
#  'beehives': 47167,
#  'mildred': 28892,
#  'erythraean': 54872,
#  'recoup': 44639,
#  'capping': 40579,
#  'ewa': 47168,
#  'others': 275,
#  'worthwhile': 25106,
#  'yum': 29382,
#  'gryphon': 50135,
#  'ibaraki': 58176,
#  'cgpm': 26759,
#  'mcnab': 50136,
#  'bres': 50137,
#  'dislocation': 31905,
#  'hulls': 20299,
#  'khosrau': 44640,
#  'bukhara': 36083,
#  'gaia': 11366,
#  'magistracy': 44641,
#  'figs': 26760,
#  'simons': 30976,
#  'angry': 6619,
#  'overture': 22542,
#  'fermilab': 37448,
#  'hattusa': 53765,
#  'crust': 9451,
#  'jon': 6879,
#  'corvus': 32826,
#  'rites': 7324,
#  'lovejoy': 44642,
#  'livelihood': 18967,
#  'clock': 2487,
#  'inherited': 4874,
#  'smiles': 37449,
#  'natufian': 45178,
#  'unexplainable': 53766,
#  'levelled': 28000,
#  'cappadocia': 31906,
#  'fassbinder': 56210,
#  'alison': 21470,
#  'muir': 24176,
#  'livonians': 50138,
#  'fonda': 26189,
#  'shahada': 47169,
#  'frigid': 58178,
#  'foodcrops': 42575,
#  'penguin': 6244,
#  'derose': 60306,
#  'grabbed': 38957,
#  'pitted': 27358,
#  'songwriters': 12744,
#  'tamias': 25641,
#  'baiting': 40581,
#  'arsenic': 11066,
#  'valencian': 20847,
#  'pedophile': 53768,
#  'cutbacks': 33807,
#  'zidane': 58180,
#  'frequented': 21471,
#  'lumbering': 50139,
#  'klaas': 49076,
#  'transept': 38958,
#  'mayer': 16458,
#  'battling': 21800,
#  'truetype': 34961,
#  'liff': 53769,
#  'latino': 9452,
#  'probability': 2696,
#  'subordinates': 22517,
#  'pain': 3371,
#  'uniformitarianism': 30156,
#  'albertine': 47171,
#  'shtml': 31049,
#  'prev': 26190,
#  'falconiformes': 36084,
#  'cnidarians': 36085,
#  'cyst': 55298,
#  'coleoptera': 58181,
#  'tut': 44644,
#  'caregiver': 50140,
#  'gions': 36086,
#  'anesthesia': 27359,
#  'spit': 20029,
#  'pastel': 50141,
#  'zoologischer': 58182,
#  'gunned': 38959,
#  'lahn': 58183,
#  'dup': 46151,
#  'profitability': 20567,
#  'salat': 50142,
#  'kannapolis': 40582,
#  'magnetron': 26761,
#  'dykes': 53770,
#  'contralto': 42464,
#  'tailors': 53730,
#  'desperate': 9773,
#  'aquatic': 10645,
#  'kaiserreich': 50399,
#  'fort': 2575,
#  'pin': 5580,
#  'interleaving': 50144,
#  'themes': 2763,
#  'plovdiv': 58184,
#  'brutal': 8599,
#  'sennett': 24211,
#  'proliferated': 33887,
#  'pseudalopex': 53121,
#  'nrms': 47173,
#  'mcg': 15504,
#  'ncaa': 9774,
#  'pimlico': 36190,
#  'aris': 47174,
#  'sopot': 58185,
#  'breastplate': 38960,
#  'wentworth': 20848,
#  'reducible': 30119,
#  'sidestep': 58186,
#  'philoctetes': 50386,
#  'audacity': 40584,
#  'hiphop': 50145,
#  'pathogen': 24178,
#  'inexplicable': 35511,
#  'eerily': 58187,
#  'mondegreens': 44645,
#  'pearce': 29383,
#  'harriers': 25107,
#  'favourites': 27361,
#  'plutarch': 11730,
#  'forensic': 17843,
#  'confidences': 58188,
#  'games': 325,
#  'bootlegs': 44646,
#  'manoeuvre': 28643,
#  'aguilar': 58189,
#  'bandai': 29384,
#  'corpuscles': 38961,
#  'covey': 50146,
#  'foundries': 58190,
#  'neal': 13043,
#  'marceau': 38962,
#  'vultures': 47690,
#  'houghton': 18296,
#  'reduce': 2101,
#  'minicomputers': 23742,
#  'hardback': 29855,
#  'interacts': 17195,
#  'favor': 2538,
#  'hyenas': 25108,
#  'samuel': 2455,
#  'agnostics': 19753,
#  'capsid': 53771,
#  'ridgeland': 53772,
#  'bergson': 12745,
#  'pondicherry': 47175,
#  'olmos': 61778,
#  'secundus': 42468,
#  'alice': 4435,
#  'rem': 24664,
#  'occidentalis': 47176,
#  'laminated': 47177,
#  'augmentation': 23743,
#  'styx': 37451,
#  'yx': 44648,
#  'night': 805,
#  'caliphates': 50428,
#  'bajan': 47178,
#  'maesa': 33809,
#  'abernathy': 44618,
#  'aid': 1536,
#  'neurosis': 58192,
#  'masaryk': 53774,
#  'gillis': 58193,
#  'muppet': 14025,
#  'rik': 34963,
#  'baal': 17844,
#  'tegmark': 40728,
#  'zoolander': 50148,
#  'torso': 18076,
#  'dzogchen': 58194,
#  'bmws': 53775,
#  'drowned': 15349,
#  'nosferatu': 36089,
#  'rnsson': 45213,
#  'perceptual': 17413,
#  'latour': 47179,
#  'kao': 36090,
#  'figurines': 30979,
#  'peak': 3011,
#  'insolence': 53777,
#  'classmate': 28644,
#  'apartheid': 9182,
#  'ozarks': 42470,
#  'ranges': 3620,
#  'fouquet': 50149,
#  'oro': 24179,
#  'judges': 3022,
#  'rnas': 53778,
#  'glycosidic': 53779,
#  'arises': 6931,
#  'mechanics': 2120,
#  'compilation': 5856,
#  'disproved': 22518,
#  'predict': 6487,
#  'garnets': 50150,
#  'simitis': 50151,
#  'deucalion': 61781,
#  'elmhurst': 58197,
#  'ponder': 33900,
#  'rabbits': 16778,
#  'factorial': 15072,
#  'bead': 14626,
#  'ni': 5965,
#  'ajaigarh': 53781,
#  'favre': 42471,
#  'harem': 33810,
#  'sheaf': 36091,
#  'goiter': 50152,
#  'empresses': 25109,
#  'transatlantic': 16340,
#  'capella': 25642,
#  'mondo': 36077,
#  'aquila': 20300,
#  'pontine': 50153,
#  'stoppard': 55758,
#  'infractions': 29385,
#  'oau': 17845,
#  'glasgow': 7892,
#  'legislatures': 16570,
#  'mite': 38963,
#  'deflationary': 50154,
#  'pastry': 24180,
#  'turks': 5711,
#  'hairy': 18968,
#  'swinburne': 23744,
#  'misread': 50155,
#  'endothelial': 53782,
#  'isbn': 271,
#  'visitors': 4251,
#  'gustaf': 20568,
#  'bombarded': 23745,
#  'macarius': 58198,
#  'louise': 10573,
#  'astrophysics': 19226,
#  'artery': 11731,
#  'engines': 2118,
#  'bernardo': 17628,
#  'guns': 2697,
#  'olof': 31908,
#  'fairly': 2800,
#  'deserves': 19500,
#  'wieser': 58199,
#  'interstellar': 9444,
#  'aloe': 8761,
#  'rocking': 31466,
#  'gaud': 15073,
#  'mulcahy': 23746,
#  'disclosing': 50157,
#  'cristiano': 53733,
#  'madness': 11817,
#  ...}

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

t=0.00001
words_c=Counter(words)
words_counts=Counter(int_words)

total_count=len(int_words)
words_freq={word: count/total_count for word, count in words_counts.items()}
for word in words_counts:
    prob[word]=1-((t/words_freq[word])**(0.5))
    
train_words = [word for word in int_words if random.random() < (1 - prob[word])]

# %%
print("of:",words_freq[vocab_to_int['of']],'and',prob[vocab_to_int['of']])
#print("anarchism:",words_freq[100],'and',prob[100])
# Out:
# of: 0.035590868169662254 and 0.9832378119313352

# %%
words_counts
# Out:
# Counter({0: 1061396,
#          1: 593677,
#          2: 416629,
#          3: 411764,
#          4: 372201,
#          5: 325873,
#          6: 316376,
#          7: 264975,
#          8: 250430,
#          9: 192644,
#          10: 183153,
#          11: 131815,
#          12: 125285,
#          13: 118445,
#          14: 116710,
#          15: 115789,
#          16: 114775,
#          17: 112807,
#          18: 111831,
#          19: 109510,
#          20: 108182,
#          21: 102145,
#          22: 99683,
#          23: 95603,
#          24: 91250,
#          25: 76527,
#          26: 73334,
#          27: 72871,
#          28: 68945,
#          29: 62603,
#          30: 61925,
#          31: 61281,
#          32: 58832,
#          33: 54788,
#          34: 54576,
#          35: 53573,
#          36: 44358,
#          37: 44033,
#          38: 39712,
#          39: 39086,
#          40: 37866,
#          41: 35358,
#          42: 32433,
#          43: 31523,
#          44: 29567,
#          45: 28810,
#          46: 28553,
#          47: 28161,
#          48: 28100,
#          49: 26229,
#          50: 26223,
#          51: 25563,
#          52: 25519,
#          53: 25383,
#          54: 24413,
#          55: 24096,
#          56: 23997,
#          57: 23770,
#          58: 22737,
#          59: 22707,
#          60: 21125,
#          61: 20623,
#          62: 20484,
#          63: 20477,
#          64: 20412,
#          65: 19864,
#          66: 19463,
#          67: 19206,
#          68: 19115,
#          69: 18807,
#          70: 17949,
#          71: 17581,
#          72: 17516,
#          73: 17377,
#          74: 17236,
#          75: 16155,
#          76: 15861,
#          77: 15737,
#          78: 15574,
#          79: 15122,
#          80: 14935,
#          81: 14916,
#          82: 14696,
#          83: 14629,
#          84: 14578,
#          85: 14494,
#          86: 14437,
#          87: 14420,
#          88: 14151,
#          89: 14011,
#          90: 13380,
#          91: 13296,
#          92: 12987,
#          93: 12904,
#          94: 12722,
#          95: 12623,
#          96: 12560,
#          97: 12445,
#          98: 12363,
#          99: 12347,
#          100: 12275,
#          101: 11931,
#          102: 11868,
#          103: 11847,
#          104: 11803,
#          105: 11755,
#          106: 11753,
#          107: 11721,
#          108: 11701,
#          109: 11537,
#          110: 11536,
#          111: 11426,
#          112: 11399,
#          113: 11323,
#          114: 11285,
#          115: 10976,
#          116: 10971,
#          117: 10691,
#          118: 10629,
#          119: 10627,
#          120: 10572,
#          121: 10561,
#          122: 10550,
#          123: 10371,
#          124: 10332,
#          125: 10307,
#          126: 10195,
#          127: 10172,
#          128: 10096,
#          129: 10056,
#          130: 9858,
#          131: 9854,
#          132: 9774,
#          133: 9633,
#          134: 9591,
#          135: 9539,
#          136: 9534,
#          137: 9500,
#          138: 9412,
#          139: 9388,
#          140: 9375,
#          141: 9286,
#          142: 9168,
#          143: 9133,
#          144: 8956,
#          145: 8928,
#          146: 8904,
#          147: 8861,
#          148: 8822,
#          149: 8773,
#          150: 8736,
#          151: 8700,
#          152: 8659,
#          153: 8581,
#          154: 8491,
#          155: 8432,
#          156: 8372,
#          157: 8337,
#          158: 8312,
#          159: 8304,
#          160: 8244,
#          161: 8209,
#          162: 8206,
#          163: 8110,
#          164: 8002,
#          165: 7987,
#          166: 7933,
#          167: 7898,
#          168: 7896,
#          169: 7878,
#          170: 7862,
#          171: 7858,
#          172: 7797,
#          173: 7790,
#          174: 7770,
#          175: 7763,
#          176: 7698,
#          177: 7682,
#          178: 7672,
#          179: 7628,
#          180: 7611,
#          181: 7585,
#          182: 7553,
#          183: 7522,
#          184: 7488,
#          185: 7481,
#          186: 7456,
#          187: 7435,
#          188: 7417,
#          189: 7400,
#          190: 7378,
#          191: 7368,
#          192: 7328,
#          193: 7262,
#          194: 7219,
#          195: 7118,
#          196: 7113,
#          197: 7110,
#          198: 7043,
#          199: 7034,
#          200: 6970,
#          201: 6943,
#          202: 6908,
#          203: 6872,
#          204: 6865,
#          205: 6786,
#          206: 6690,
#          207: 6684,
#          208: 6604,
#          209: 6591,
#          210: 6576,
#          211: 6531,
#          212: 6518,
#          213: 6494,
#          214: 6433,
#          215: 6419,
#          216: 6410,
#          217: 6400,
#          218: 6384,
#          219: 6362,
#          220: 6361,
#          221: 6300,
#          222: 6238,
#          223: 6220,
#          224: 6184,
#          225: 6184,
#          226: 6166,
#          227: 6146,
#          228: 6141,
#          229: 6064,
#          230: 6056,
#          231: 6001,
#          232: 5985,
#          233: 5976,
#          234: 5967,
#          235: 5874,
#          236: 5862,
#          237: 5857,
#          238: 5854,
#          239: 5844,
#          240: 5843,
#          241: 5806,
#          242: 5778,
#          243: 5761,
#          244: 5758,
#          245: 5711,
#          246: 5684,
#          247: 5678,
#          248: 5661,
#          249: 5654,
#          250: 5652,
#          251: 5634,
#          252: 5605,
#          253: 5582,
#          254: 5468,
#          255: 5450,
#          256: 5404,
#          257: 5350,
#          258: 5345,
#          259: 5343,
#          260: 5319,
#          261: 5314,
#          262: 5289,
#          263: 5268,
#          264: 5262,
#          265: 5248,
#          266: 5246,
#          267: 5243,
#          268: 5236,
#          269: 5231,
#          270: 5221,
#          271: 5216,
#          272: 5207,
#          273: 5196,
#          274: 5163,
#          275: 5160,
#          276: 5157,
#          277: 5143,
#          278: 5124,
#          279: 5113,
#          280: 5108,
#          281: 5105,
#          282: 5099,
#          283: 5096,
#          284: 5094,
#          285: 5087,
#          286: 5070,
#          287: 5025,
#          288: 5013,
#          289: 5010,
#          290: 5007,
#          291: 5004,
#          292: 4979,
#          293: 4974,
#          294: 4970,
#          295: 4939,
#          296: 4916,
#          297: 4910,
#          298: 4902,
#          299: 4898,
#          300: 4884,
#          301: 4872,
#          302: 4813,
#          303: 4802,
#          304: 4801,
#          305: 4776,
#          306: 4762,
#          307: 4755,
#          308: 4731,
#          309: 4728,
#          310: 4727,
#          311: 4724,
#          312: 4721,
#          313: 4720,
#          314: 4686,
#          315: 4641,
#          316: 4612,
#          317: 4605,
#          318: 4586,
#          319: 4586,
#          320: 4577,
#          321: 4574,
#          322: 4551,
#          323: 4539,
#          324: 4528,
#          325: 4527,
#          326: 4483,
#          327: 4472,
#          328: 4471,
#          329: 4457,
#          330: 4448,
#          331: 4446,
#          332: 4435,
#          333: 4433,
#          334: 4430,
#          335: 4429,
#          336: 4418,
#          337: 4414,
#          338: 4399,
#          339: 4386,
#          340: 4383,
#          341: 4352,
#          342: 4347,
#          343: 4330,
#          344: 4307,
#          345: 4307,
#          346: 4299,
#          347: 4270,
#          348: 4269,
#          349: 4268,
#          350: 4260,
#          351: 4257,
#          352: 4241,
#          353: 4236,
#          354: 4231,
#          355: 4212,
#          356: 4202,
#          357: 4198,
#          358: 4193,
#          359: 4178,
#          360: 4176,
#          361: 4172,
#          362: 4165,
#          363: 4127,
#          364: 4125,
#          365: 4121,
#          366: 4118,
#          367: 4114,
#          368: 4114,
#          369: 4105,
#          370: 4078,
#          371: 4067,
#          372: 4064,
#          373: 4063,
#          374: 4051,
#          375: 4042,
#          376: 4034,
#          377: 4013,
#          378: 4007,
#          379: 3992,
#          380: 3985,
#          381: 3984,
#          382: 3978,
#          383: 3964,
#          384: 3962,
#          385: 3960,
#          386: 3955,
#          387: 3955,
#          388: 3949,
#          389: 3947,
#          390: 3922,
#          391: 3919,
#          392: 3903,
#          393: 3891,
#          394: 3874,
#          395: 3866,
#          396: 3863,
#          397: 3855,
#          398: 3843,
#          399: 3831,
#          400: 3809,
#          401: 3805,
#          402: 3782,
#          403: 3773,
#          404: 3772,
#          405: 3771,
#          406: 3768,
#          407: 3767,
#          408: 3762,
#          409: 3760,
#          410: 3760,
#          411: 3755,
#          412: 3747,
#          413: 3745,
#          414: 3734,
#          415: 3726,
#          416: 3717,
#          417: 3714,
#          418: 3714,
#          419: 3708,
#          420: 3702,
#          421: 3698,
#          422: 3691,
#          423: 3686,
#          424: 3675,
#          425: 3663,
#          426: 3662,
#          427: 3653,
#          428: 3650,
#          429: 3639,
#          430: 3616,
#          431: 3611,
#          432: 3611,
#          433: 3601,
#          434: 3599,
#          435: 3595,
#          436: 3588,
#          437: 3588,
#          438: 3583,
#          439: 3581,
#          440: 3573,
#          441: 3572,
#          442: 3570,
#          443: 3555,
#          444: 3548,
#          445: 3546,
#          446: 3545,
#          447: 3536,
#          448: 3528,
#          449: 3524,
#          450: 3523,
#          451: 3519,
#          452: 3519,
#          453: 3503,
#          454: 3502,
#          455: 3493,
#          456: 3483,
#          457: 3464,
#          458: 3457,
#          459: 3452,
#          460: 3451,
#          461: 3448,
#          462: 3443,
#          463: 3443,
#          464: 3442,
#          465: 3441,
#          466: 3438,
#          467: 3437,
#          468: 3437,
#          469: 3437,
#          470: 3435,
#          471: 3430,
#          472: 3429,
#          473: 3428,
#          474: 3423,
#          475: 3418,
#          476: 3412,
#          477: 3410,
#          478: 3406,
#          479: 3404,
#          480: 3403,
#          481: 3401,
#          482: 3395,
#          483: 3376,
#          484: 3368,
#          485: 3365,
#          486: 3363,
#          487: 3360,
#          488: 3356,
#          489: 3356,
#          490: 3352,
#          491: 3333,
#          492: 3330,
#          493: 3318,
#          494: 3311,
#          495: 3310,
#          496: 3307,
#          497: 3304,
#          498: 3303,
#          499: 3301,
#          500: 3290,
#          501: 3277,
#          502: 3276,
#          503: 3268,
#          504: 3266,
#          505: 3259,
#          506: 3248,
#          507: 3242,
#          508: 3242,
#          509: 3240,
#          510: 3213,
#          511: 3213,
#          512: 3207,
#          513: 3206,
#          514: 3195,
#          515: 3185,
#          516: 3176,
#          517: 3141,
#          518: 3136,
#          519: 3135,
#          520: 3133,
#          521: 3131,
#          522: 3129,
#          523: 3125,
#          524: 3119,
#          525: 3119,
#          526: 3109,
#          527: 3103,
#          528: 3102,
#          529: 3098,
#          530: 3088,
#          531: 3079,
#          532: 3069,
#          533: 3063,
#          534: 3055,
#          535: 3050,
#          536: 3050,
#          537: 3046,
#          538: 3044,
#          539: 3043,
#          540: 3043,
#          541: 3037,
#          542: 3035,
#          543: 3027,
#          544: 3022,
#          545: 3017,
#          546: 3011,
#          547: 3009,
#          548: 3002,
#          549: 3002,
#          550: 2989,
#          551: 2965,
#          552: 2964,
#          553: 2963,
#          554: 2961,
#          555: 2959,
#          556: 2935,
#          557: 2933,
#          558: 2932,
#          559: 2927,
#          560: 2923,
#          561: 2914,
#          562: 2913,
#          563: 2899,
#          564: 2895,
#          565: 2888,
#          566: 2882,
#          567: 2879,
#          568: 2876,
#          569: 2863,
#          570: 2857,
#          571: 2852,
#          572: 2852,
#          573: 2845,
#          574: 2843,
#          575: 2830,
#          576: 2829,
#          577: 2822,
#          578: 2821,
#          579: 2819,
#          580: 2819,
#          581: 2817,
#          582: 2810,
#          583: 2809,
#          584: 2806,
#          585: 2806,
#          586: 2797,
#          587: 2796,
#          588: 2795,
#          589: 2795,
#          590: 2785,
#          591: 2784,
#          592: 2777,
#          593: 2775,
#          594: 2773,
#          595: 2771,
#          596: 2771,
#          597: 2769,
#          598: 2767,
#          599: 2761,
#          600: 2759,
#          601: 2759,
#          602: 2758,
#          603: 2755,
#          604: 2753,
#          605: 2752,
#          606: 2748,
#          607: 2746,
#          608: 2745,
#          609: 2741,
#          610: 2740,
#          611: 2736,
#          612: 2735,
#          613: 2731,
#          614: 2731,
#          615: 2727,
#          616: 2723,
#          617: 2722,
#          618: 2719,
#          619: 2716,
#          620: 2714,
#          621: 2709,
#          622: 2708,
#          623: 2699,
#          624: 2697,
#          625: 2693,
#          626: 2693,
#          627: 2691,
#          628: 2685,
#          629: 2681,
#          630: 2674,
#          631: 2664,
#          632: 2663,
#          633: 2660,
#          634: 2650,
#          635: 2644,
#          636: 2638,
#          637: 2633,
#          638: 2632,
#          639: 2628,
#          640: 2628,
#          641: 2623,
#          642: 2620,
#          643: 2619,
#          644: 2615,
#          645: 2595,
#          646: 2595,
#          647: 2593,
#          648: 2583,
#          649: 2576,
#          650: 2574,
#          651: 2562,
#          652: 2561,
#          653: 2554,
#          654: 2554,
#          655: 2553,
#          656: 2542,
#          657: 2540,
#          658: 2539,
#          659: 2537,
#          660: 2530,
#          661: 2527,
#          662: 2525,
#          663: 2525,
#          664: 2520,
#          665: 2519,
#          666: 2518,
#          667: 2494,
#          668: 2493,
#          669: 2493,
#          670: 2489,
#          671: 2480,
#          672: 2478,
#          673: 2475,
#          674: 2471,
#          675: 2471,
#          676: 2470,
#          677: 2468,
#          678: 2464,
#          679: 2462,
#          680: 2461,
#          681: 2458,
#          682: 2457,
#          683: 2456,
#          684: 2454,
#          685: 2451,
#          686: 2449,
#          687: 2444,
#          688: 2440,
#          689: 2439,
#          690: 2434,
#          691: 2432,
#          692: 2431,
#          693: 2404,
#          694: 2404,
#          695: 2398,
#          696: 2397,
#          697: 2397,
#          698: 2396,
#          699: 2395,
#          700: 2392,
#          701: 2389,
#          702: 2384,
#          703: 2380,
#          704: 2379,
#          705: 2379,
#          706: 2376,
#          707: 2375,
#          708: 2374,
#          709: 2373,
#          710: 2364,
#          711: 2362,
#          712: 2361,
#          713: 2359,
#          714: 2357,
#          715: 2356,
#          716: 2353,
#          717: 2349,
#          718: 2349,
#          719: 2343,
#          720: 2337,
#          721: 2336,
#          722: 2336,
#          723: 2331,
#          724: 2319,
#          725: 2313,
#          726: 2313,
#          727: 2308,
#          728: 2304,
#          729: 2303,
#          730: 2300,
#          731: 2299,
#          732: 2298,
#          733: 2296,
#          734: 2290,
#          735: 2289,
#          736: 2288,
#          737: 2282,
#          738: 2278,
#          739: 2275,
#          740: 2272,
#          741: 2271,
#          742: 2267,
#          743: 2266,
#          744: 2260,
#          745: 2256,
#          746: 2255,
#          747: 2252,
#          748: 2251,
#          749: 2249,
#          750: 2249,
#          751: 2248,
#          752: 2243,
#          753: 2241,
#          754: 2236,
#          755: 2231,
#          756: 2231,
#          757: 2227,
#          758: 2223,
#          759: 2222,
#          760: 2222,
#          761: 2218,
#          762: 2217,
#          763: 2216,
#          764: 2215,
#          765: 2206,
#          766: 2200,
#          767: 2195,
#          768: 2194,
#          769: 2193,
#          770: 2192,
#          771: 2189,
#          772: 2183,
#          773: 2182,
#          774: 2178,
#          775: 2178,
#          776: 2177,
#          777: 2175,
#          778: 2174,
#          779: 2171,
#          780: 2168,
#          781: 2164,
#          782: 2163,
#          783: 2162,
#          784: 2162,
#          785: 2159,
#          786: 2156,
#          787: 2147,
#          788: 2139,
#          789: 2137,
#          790: 2133,
#          791: 2133,
#          792: 2130,
#          793: 2128,
#          794: 2126,
#          795: 2125,
#          796: 2124,
#          797: 2119,
#          798: 2117,
#          799: 2116,
#          800: 2115,
#          801: 2114,
#          802: 2111,
#          803: 2109,
#          804: 2109,
#          805: 2108,
#          806: 2108,
#          807: 2108,
#          808: 2105,
#          809: 2103,
#          810: 2102,
#          811: 2102,
#          812: 2102,
#          813: 2101,
#          814: 2101,
#          815: 2099,
#          816: 2099,
#          817: 2098,
#          818: 2098,
#          819: 2093,
#          820: 2093,
#          821: 2090,
#          822: 2090,
#          823: 2089,
#          824: 2086,
#          825: 2084,
#          826: 2080,
#          827: 2079,
#          828: 2074,
#          829: 2070,
#          830: 2069,
#          831: 2069,
#          832: 2068,
#          833: 2067,
#          834: 2066,
#          835: 2065,
#          836: 2064,
#          837: 2060,
#          838: 2059,
#          839: 2057,
#          840: 2054,
#          841: 2052,
#          842: 2050,
#          843: 2049,
#          844: 2048,
#          845: 2045,
#          846: 2042,
#          847: 2041,
#          848: 2039,
#          849: 2034,
#          850: 2033,
#          851: 2033,
#          852: 2031,
#          853: 2030,
#          854: 2029,
#          855: 2026,
#          856: 2025,
#          857: 2024,
#          858: 2022,
#          859: 2021,
#          860: 2020,
#          861: 2018,
#          862: 2017,
#          863: 2013,
#          864: 2013,
#          865: 2013,
#          866: 2012,
#          867: 2009,
#          868: 2007,
#          869: 2005,
#          870: 2000,
#          871: 1995,
#          872: 1994,
#          873: 1992,
#          874: 1990,
#          875: 1989,
#          876: 1981,
#          877: 1980,
#          878: 1977,
#          879: 1977,
#          880: 1977,
#          881: 1973,
#          882: 1971,
#          883: 1967,
#          884: 1966,
#          885: 1959,
#          886: 1959,
#          887: 1958,
#          888: 1958,
#          889: 1957,
#          890: 1954,
#          891: 1952,
#          892: 1950,
#          893: 1948,
#          894: 1945,
#          895: 1945,
#          896: 1945,
#          897: 1944,
#          898: 1944,
#          899: 1944,
#          900: 1941,
#          901: 1941,
#          902: 1940,
#          903: 1938,
#          904: 1938,
#          905: 1938,
#          906: 1936,
#          907: 1935,
#          908: 1934,
#          909: 1930,
#          910: 1927,
#          911: 1926,
#          912: 1924,
#          913: 1924,
#          914: 1922,
#          915: 1921,
#          916: 1919,
#          917: 1918,
#          918: 1916,
#          919: 1915,
#          920: 1914,
#          921: 1913,
#          922: 1912,
#          923: 1911,
#          924: 1907,
#          925: 1905,
#          926: 1904,
#          927: 1904,
#          928: 1903,
#          929: 1903,
#          930: 1902,
#          931: 1900,
#          932: 1899,
#          933: 1897,
#          934: 1896,
#          935: 1896,
#          936: 1895,
#          937: 1895,
#          938: 1892,
#          939: 1890,
#          940: 1888,
#          941: 1887,
#          942: 1887,
#          943: 1883,
#          944: 1881,
#          945: 1880,
#          946: 1872,
#          947: 1871,
#          948: 1870,
#          949: 1868,
#          950: 1866,
#          951: 1865,
#          952: 1864,
#          953: 1862,
#          954: 1861,
#          955: 1860,
#          956: 1859,
#          957: 1858,
#          958: 1858,
#          959: 1857,
#          960: 1856,
#          961: 1854,
#          962: 1852,
#          963: 1852,
#          964: 1851,
#          965: 1849,
#          966: 1843,
#          967: 1843,
#          968: 1842,
#          969: 1841,
#          970: 1840,
#          971: 1836,
#          972: 1830,
#          973: 1828,
#          974: 1823,
#          975: 1823,
#          976: 1819,
#          977: 1819,
#          978: 1813,
#          979: 1812,
#          980: 1811,
#          981: 1810,
#          982: 1809,
#          983: 1808,
#          984: 1807,
#          985: 1807,
#          986: 1806,
#          987: 1805,
#          988: 1802,
#          989: 1801,
#          990: 1801,
#          991: 1800,
#          992: 1797,
#          993: 1794,
#          994: 1790,
#          995: 1789,
#          996: 1787,
#          997: 1786,
#          998: 1783,
#          999: 1783,
#          ...})

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R=1+int(4*random.random())
    #print(R)
    start = idx-R if (idx-R)> 0 else 0
    target_list =set(words[start:idx]+words[idx+1:idx+R+1])
    
    
    return list(target_list)

# %%
get_target(words,60,5)
# Out:
# ['up', 'label', 'as', 'by', 'positive', 'taken']

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32,shape=[None],name='inputs')
    labels = tf.placeholder(tf.int32,shape=[None,None], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 
with train_graph.as_default():
    embedding =tf.Variable(tf.random_uniform(shape=(n_vocab,n_embedding),minval=-1,maxval=1))
    embed = tf.nn.embedding_lookup(embedding,inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal(shape=(n_vocab,n_embedding),stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b,labels,embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6440 0.4365 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5865 0.3688 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4922 0.4096 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5896 0.3456 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5080 0.3155 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5114 0.3478 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5528 0.4125 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5405 0.3940 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4643 0.5978 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4159 0.4321 sec/batch
# Nearest to about: balding, kfor, klaviertrio, arise, raf, extractor, month, mnemosyne,
# Nearest to one: autrefois, preprocessor, chr, perpendicular, yevgeny, montag, escola, leningrad,
# Nearest to at: contained, endothermic, consummate, rethink, suffered, gift, distributing, detox,
# Nearest to more: bitrates, haunt, duns, gwangju, tonsils, etymological, unqualified, growths,
# Nearest to history: dao, senayan, charity, ariana, copland, poum, teenage, jehu,
# Nearest to if: bhangra, ncc, concise, loco, plath, epochs, mori, temperate,
# Nearest to war: gotlanders, projekt, calhoun, slaughtering, gabonese, deviation, moderate, nh,
# Nearest to had: supervillain, merely, nitrates, herds, ravaging, skew, insurmountable, sufis,
# Nearest to applied: fraggle, usefulness, maps, standing, fraught, barristers, insert, warfare,
# Nearest to assembly: malatesta, eelam, dense, intensify, czi, southernmost, gaulois, redfield,
# Nearest to troops: horkheimer, samson, were, manitou, roommates, impressive, nagaoka, congregate,
# Nearest to engine: laugh, penning, belgique, margaret, abuser, legislators, overflows, deflationary,
# Nearest to mean: leno, shoes, phthalocyanine, bouzouki, nous, heightened, luka, losing,
# Nearest to existence: quartier, pursuant, coincidences, duality, dethroned, imbolc, salford, southwest,
# Nearest to magazine: equates, toxicology, albicans, vijayanagara, devoted, crosswise, wolfhound, coordinate,
# Nearest to joseph: marcian, vdash, flybys, michio, bayreuth, sams, sceptre, solved,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5230 0.3517 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3785 0.3676 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3949 0.3128 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.3688 0.3304 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2911 0.3823 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.2764 0.3477 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.2292 0.4414 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.2182 0.3758 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.1750 0.3584 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.1451 0.3085 sec/batch
# Nearest to about: raf, arise, month, kfor, balding, extractor, klaviertrio, depict,
# Nearest to one: autrefois, preprocessor, chr, removed, perpendicular, six, leningrad, shallow,
# Nearest to at: america, contained, suffered, years, endothermic, gift, sports, tinged,
# Nearest to more: gradually, bitrates, duns, affecting, already, haunt, etymological, unqualified,
# Nearest to history: dao, ariana, lsa, charity, egypt, senayan, teenage, copland,
# Nearest to if: concise, ncc, temperate, huck, governed, strip, b, bhangra,
# Nearest to war: gotlanders, projekt, calhoun, slaughtering, moderate, size, horribly, visualize,
# Nearest to had: merely, supervillain, nitrates, ravaging, units, live, insurmountable, norton,
# Nearest to applied: usefulness, fraggle, standing, maps, ultimate, maple, fraught, warfare,
# Nearest to assembly: malatesta, eelam, southernmost, dense, gaulois, seeger, czi, intensify,
# Nearest to troops: were, impressive, horkheimer, samson, its, manitou, roommates, congregate,
# Nearest to engine: laugh, penning, belgique, margaret, unreasonable, legislators, deflationary, newspaperman,
# Nearest to mean: leno, shoes, losing, phthalocyanine, heightened, bouzouki, syrup, slows,
# Nearest to existence: pursuant, quartier, coincidences, southwest, duality, dethroned, imbolc, ericales,
# Nearest to magazine: toxicology, equates, devoted, coordinate, albicans, vijayanagara, crosswise, wolfhound,
# Nearest to joseph: marcian, vdash, michio, flybys, solved, sams, sceptre, bayreuth,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 5.0599 0.3057 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 5.0616 0.3161 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 5.0171 0.3127 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.9950 0.3324 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.9043 0.3041 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.9248 0.2989 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8760 0.3573 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8443 0.3752 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8381 0.3512 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8306 0.3469 sec/batch
# Nearest to about: arise, raf, month, kfor, extractor, know, balding, reliefs,
# Nearest to one: autrefois, six, perpendicular, nazi, preprocessor, shallow, growth, chr,
# Nearest to at: contained, suffered, america, endothermic, years, gift, distributing, sports,
# Nearest to more: gradually, duns, etymological, attention, affecting, bitrates, somewhere, ideological,
# Nearest to history: dao, charity, egypt, teenage, ariana, acceptable, delayed, initially,
# Nearest to if: concise, temperate, governed, huck, rate, negative, ncc, requisite,
# Nearest to war: gotlanders, moderate, projekt, calhoun, horribly, averse, slaughtering, visualize,
# Nearest to had: merely, supervillain, ones, formally, nitrates, units, ravaging, herds,
# Nearest to applied: usefulness, standing, maps, fraggle, ultimate, insert, warfare, corresponds,
# Nearest to assembly: malatesta, eelam, collaboration, seeger, southernmost, dense, battlefield, gaulois,
# Nearest to troops: were, impressive, its, colonists, samson, wounded, influence, horkheimer,
# Nearest to engine: laugh, margaret, penning, belgique, legislators, unreasonable, paying, doses,
# Nearest to mean: leno, losing, shoes, does, slows, knighthood, hosted, spare,
# Nearest to existence: pursuant, coincidences, southwest, quartier, duality, dethroned, attributed, imbolc,
# Nearest to magazine: coordinate, devoted, sides, made, equates, toxicology, discontinuous, albicans,
# Nearest to joseph: marcian, vdash, michio, solved, flybys, sceptre, curricula, freely,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8038 0.3689 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7884 0.3157 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7517 0.3137 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7388 0.3305 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7807 0.3174 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7449 0.3179 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7345 0.3202 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7386 0.3221 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7233 0.3581 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6601 0.3485 sec/batch
# Nearest to about: arise, raf, kfor, month, balding, mnemosyne, extractor, insurgency,
# Nearest to one: six, eight, leningrad, seven, autrefois, nazi, chr, growth,
# Nearest to at: contained, suffered, america, distributing, steep, endothermic, tinged, gift,
# Nearest to more: bitrates, duns, affecting, gradually, attention, worthy, etymological, trail,
# Nearest to history: charity, dao, pavel, egypt, teenage, persona, ariana, ties,
# Nearest to if: concise, temperate, huck, requisite, governed, negative, message, concentrations,
# Nearest to war: gotlanders, moderate, projekt, horribly, willy, scholar, east, francis,
# Nearest to had: merely, nitrates, supervillain, martyr, lebanon, herds, norton, insurmountable,
# Nearest to applied: usefulness, standing, fraggle, maps, ultimate, insert, warfare, maple,
# Nearest to assembly: malatesta, eelam, battlefield, seeger, southernmost, collaboration, bohemian, czi,
# Nearest to troops: were, colonists, impressive, samson, wounded, its, roommates, horkheimer,
# Nearest to engine: laugh, penning, belgique, legislators, paying, deflationary, doses, unreasonable,
# Nearest to mean: leno, slows, losing, does, rabbi, shoes, laugh, sides,
# Nearest to existence: quartier, coincidences, pursuant, duality, dethroned, southwest, attributed, demand,
# Nearest to magazine: devoted, coordinate, equates, vijayanagara, discontinuous, sides, albicans, toxicology,
# Nearest to joseph: vdash, marcian, michio, reputation, sceptre, curricula, nonetheless, flybys,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6697 0.3133 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6654 0.3196 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6076 0.3328 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6379 0.2973 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6240 0.3187 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6163 0.3031 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5627 0.2360 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5292 0.3125 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4643 0.3120 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4681 0.3621 sec/batch
# Nearest to about: arise, raf, kfor, balding, extractor, mnemosyne, month, murdering,
# Nearest to one: six, eight, seven, william, leningrad, autrefois, mcintyre, two,
# Nearest to at: suffered, america, contained, distributing, animism, endothermic, tinged, sports,
# Nearest to more: bitrates, duns, metaphors, affecting, etymological, specifications, somewhere, attention,
# Nearest to history: charity, dao, pavel, egypt, copland, persona, senayan, distributing,
# Nearest to if: huck, temperate, concise, defined, negative, message, requisite, governed,
# Nearest to war: moderate, gotlanders, projekt, horribly, east, willy, scholar, militia,
# Nearest to had: merely, nitrates, supervillain, lebanon, martyr, punishable, herds, insurmountable,
# Nearest to applied: usefulness, fraggle, maps, ultimate, standing, insert, differs, barristers,
# Nearest to assembly: malatesta, eelam, battlefield, seeger, intensify, czi, devolved, southernmost,
# Nearest to troops: colonists, were, wounded, roommates, samson, horkheimer, impressive, amsterdam,
# Nearest to engine: laugh, belgique, penning, legislators, deflationary, doses, refinements, paying,
# Nearest to mean: leno, slows, does, laugh, losing, shoes, sides, rabbi,
# Nearest to existence: coincidences, quartier, pursuant, duality, dethroned, hobbyists, southwest, imbolc,
# Nearest to magazine: devoted, coordinate, equates, deserving, vijayanagara, toxicology, sides, albicans,
# Nearest to joseph: vdash, sceptre, michio, marcian, reaffirmed, flybys, curricula, polyanin,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4544 0.3309 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4599 0.3268 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4239 0.3183 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.4646 0.3505 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4473 0.3455 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4018 0.3093 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4355 0.3329 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3408 0.3643 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.3782 0.4329 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.3748 0.4849 sec/batch
# Nearest to about: kfor, raf, arise, balding, crazy, kastrioti, month, mnemosyne,
# Nearest to one: six, eight, seven, mcintyre, autrefois, leningrad, two, william,
# Nearest to at: suffered, contained, america, consummate, animism, tinged, distributing, endothermic,
# Nearest to more: bitrates, affecting, duns, metaphors, etymological, somewhere, growths, gradually,
# Nearest to history: charity, dao, pavel, egypt, senayan, copland, encounter, enlai,
# Nearest to if: huck, defined, negative, disconcerting, message, requisite, indicate, value,
# Nearest to war: moderate, horribly, republic, gotlanders, east, projekt, willy, militia,
# Nearest to had: nitrates, martyr, slaves, lebanon, merely, formally, supervillain, insurmountable,
# Nearest to applied: usefulness, fraggle, maps, standing, barristers, insert, ultimate, differs,
# Nearest to assembly: malatesta, eelam, seeger, intensify, battlefield, devolved, czi, culminate,
# Nearest to troops: were, colonists, wounded, roommates, amsterdam, augusti, impressive, horkheimer,
# Nearest to engine: laugh, belgique, penning, refinements, legislators, doses, deflationary, nanometers,
# Nearest to mean: leno, slows, does, laugh, rabbi, modulo, bouzouki, generated,
# Nearest to existence: coincidences, quartier, pursuant, duality, hobbyists, dethroned, maintaining, treated,
# Nearest to magazine: devoted, coordinate, equates, deserving, vijayanagara, albicans, punitive, earning,
# Nearest to joseph: vdash, michio, tfl, marcian, sceptre, ousted, reaffirmed, polyanin,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.3646 0.3890 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3338 0.3381 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.3636 0.3225 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3681 0.3147 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3409 0.3194 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.3924 0.3206 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.2970 0.3121 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3227 0.3070 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3556 0.3070 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3179 0.3063 sec/batch
# Nearest to about: kfor, arise, know, extractor, kastrioti, balding, raf, crazy,
# Nearest to one: six, eight, seven, two, nine, mcintyre, industrialist, william,
# Nearest to at: suffered, america, contained, animism, consummate, rethink, tinged, endothermic,
# Nearest to more: bitrates, duns, affecting, metaphors, growths, worthy, etymological, specifications,
# Nearest to history: charity, dao, pavel, egypt, copland, icc, syndicates, enlai,
# Nearest to if: huck, defined, negative, requisite, disconcerting, value, message, concise,
# Nearest to war: moderate, horribly, republic, gotlanders, projekt, soviet, east, militia,
# Nearest to had: slaves, nitrates, martyr, lebanon, alveoli, formally, insurmountable, grandson,
# Nearest to applied: usefulness, fraggle, differs, maps, standing, barristers, insert, ultimate,
# Nearest to assembly: malatesta, eelam, representatives, elections, devolved, seeger, czi, battlefield,
# Nearest to troops: colonists, wounded, were, republics, roommates, augusti, amsterdam, samson,
# Nearest to engine: belgique, laugh, refinements, plugs, doses, penning, legislators, pediatrics,
# Nearest to mean: leno, slows, laugh, does, modulo, brushing, rabbi, complete,
# Nearest to existence: coincidences, duality, quartier, pursuant, treated, trump, hobbyists, maintaining,
# Nearest to magazine: devoted, coordinate, albicans, vijayanagara, deserving, aphra, equates, earning,
# Nearest to joseph: vdash, sceptre, tfl, reaffirmed, michio, ousted, marcian, polyanin,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.2861 0.3157 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3304 0.3194 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3015 0.3083 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.2950 0.3097 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3441 0.3078 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3123 0.3088 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3471 0.3067 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3099 0.3121 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.2637 0.3078 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.2507 0.3028 sec/batch
# Nearest to about: kastrioti, kfor, balding, know, arise, extractor, month, raf,
# Nearest to one: six, eight, two, seven, nine, autrefois, industrialist, banknotes,
# Nearest to at: suffered, america, contained, rethink, continuing, animism, consummate, tinged,
# Nearest to more: bitrates, growths, specifications, affecting, duns, tonsils, worthy, congruent,
# Nearest to history: dao, egypt, charity, pavel, icc, npd, copland, belmondo,
# Nearest to if: huck, defined, value, negative, disconcerting, requisite, message, epochs,
# Nearest to war: soviet, horribly, moderate, gotlanders, republic, treaty, norwegians, seize,
# Nearest to had: slaves, nitrates, merely, lebanon, martyr, before, alveoli, slipping,
# Nearest to applied: usefulness, differs, fraggle, barristers, standing, originally, maps, manufactures,
# Nearest to assembly: malatesta, representatives, devolved, elections, intensify, czi, eelam, quranic,
# Nearest to troops: colonists, wounded, were, army, republics, roommates, augusti, forces,
# Nearest to engine: belgique, laugh, refinements, plugs, handlers, clock, pediatrics, projective,
# Nearest to mean: slows, leno, modulo, brushing, does, laugh, generated, mistresses,
# Nearest to existence: coincidences, duality, quartier, pursuant, trump, treated, maintaining, attributed,
# Nearest to magazine: devoted, albicans, vijayanagara, coordinate, earning, aphra, equates, deserving,
# Nearest to joseph: vdash, bayreuth, tfl, dirk, reaffirmed, sceptre, ousted, moscow,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.2954 0.3193 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2338 0.3118 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3278 0.3119 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3031 0.3089 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3199 0.3350 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2314 0.3464 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2561 0.4061 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.2704 0.3932 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.1365 0.3287 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2311 0.3121 sec/batch
# Nearest to about: kastrioti, balding, kfor, month, extractor, raf, crazy, arise,
# Nearest to one: six, eight, two, seven, nine, industrialist, mcintyre, five,
# Nearest to at: suffered, america, contained, rethink, continuing, matzoh, tinged, attractiveness,
# Nearest to more: bitrates, affecting, gradually, growths, drought, tahuantinsuyu, congruent, ambitious,
# Nearest to history: npd, dao, pavel, charity, egypt, senayan, icc, caen,
# Nearest to if: huck, negative, value, defined, disconcerting, requisite, message, tell,
# Nearest to war: soviet, moderate, seize, horribly, silesia, infantry, militia, gotlanders,
# Nearest to had: before, martyr, lebanon, merely, grandson, slaves, alveoli, slipping,
# Nearest to applied: usefulness, differs, originally, fraggle, barristers, standing, maps, ultimate,
# Nearest to assembly: malatesta, representatives, elections, parliamentary, devolved, appoints, senate, eelam,
# Nearest to troops: colonists, wounded, were, army, forces, republics, roommates, resented,
# Nearest to engine: belgique, plugs, handlers, nanometers, pediatrics, refinements, laugh, clock,
# Nearest to mean: modulo, slows, does, brushing, leno, laugh, generated, vanishes,
# Nearest to existence: coincidences, duality, quartier, treated, pursuant, trump, attributed, maintaining,
# Nearest to magazine: devoted, albicans, vijayanagara, earning, aphra, strikeout, erdrich, deserving,
# Nearest to joseph: vdash, bayreuth, dirk, tfl, nicholson, sta, michio, mahatma,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2461 0.3158 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2003 0.3098 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.2821 0.1445 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.1724 0.3106 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.1034 0.3105 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1167 0.3084 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1183 0.3128 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1221 0.3481 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1190 0.3201 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.0817 0.3176 sec/batch
# Nearest to about: kastrioti, balding, month, kfor, know, extractor, hemisphere, crazy,
# Nearest to one: six, eight, two, seven, nine, mcintyre, industrialist, banknotes,
# Nearest to at: suffered, matzoh, rethink, america, contained, hyundai, continuing, tinged,
# Nearest to more: bitrates, gradually, growths, tonsils, ambitious, congruent, metaphors, tahuantinsuyu,
# Nearest to history: npd, charity, egypt, pavel, senayan, dao, schengen, icc,
# Nearest to if: huck, requisite, disconcerting, negative, tell, befall, rallying, value,
# Nearest to war: soviet, seize, infantry, moderate, horribly, neutrality, pershing, gotlanders,
# Nearest to had: before, grandson, slaves, martyr, punishable, ensured, merely, deeps,
# Nearest to applied: usefulness, barristers, differs, manufactures, fraggle, originally, standing, ultimate,
# Nearest to assembly: malatesta, representatives, elections, parliamentary, appoints, devolved, senate, intensify,
# Nearest to troops: colonists, wounded, were, army, forces, roommates, resented, landing,
# Nearest to engine: belgique, plugs, ntsc, clock, handlers, refinements, pediatrics, nanometers,
# Nearest to mean: modulo, brushing, vanishes, slows, does, laugh, bouzouki, rabbi,
# Nearest to existence: coincidences, duality, quartier, pursuant, maintaining, trump, treated, attributed,
# Nearest to magazine: devoted, albicans, vijayanagara, strikeout, equates, earning, coordinate, aphra,
# Nearest to joseph: bayreuth, vdash, sta, dirk, tfl, mathematician, nicholson, michio,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.1535 0.3205 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1361 0.3055 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1039 0.3073 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.0376 0.3129 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.0664 0.3093 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.0555 0.3258 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.0412 0.3329 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.0831 0.3112 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.0943 0.3093 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.0346 0.3230 sec/batch
# Nearest to about: kastrioti, month, know, kfor, balding, extractor, eustathius, crazy,
# Nearest to one: six, eight, two, seven, nine, mcintyre, five, zero,
# Nearest to at: suffered, matzoh, rethink, contained, continuing, ankan, electorates, courtyards,
# Nearest to more: bitrates, gradually, acceptable, basilides, ambitious, ivies, etymological, metaphors,
# Nearest to history: npd, dao, schengen, egypt, senayan, charity, geographers, pavel,
# Nearest to if: huck, defined, value, negative, disconcerting, requisite, tell, befall,
# Nearest to war: soviet, infantry, pershing, moderate, seize, neutrality, norwegians, gotlanders,
# Nearest to had: grandson, before, martyr, retire, merciful, holding, ensured, slaves,
# Nearest to applied: usefulness, barristers, differs, manufactures, originally, fraggle, standing, maps,
# Nearest to assembly: representatives, malatesta, elections, parliamentary, senate, appoints, devolved, referendum,
# Nearest to troops: wounded, colonists, army, were, forces, roommates, commander, invasion,
# Nearest to engine: belgique, plugs, ntsc, clock, nanometers, handlers, pediatrics, projective,
# Nearest to mean: vanishes, modulo, brushing, rabbi, slows, laugh, phthalocyanine, disestablishment,
# Nearest to existence: coincidences, duality, quartier, trump, pursuant, treated, maintaining, attributed,
# Nearest to magazine: devoted, strikeout, albicans, equates, vijayanagara, earning, aphra, fansite,
# Nearest to joseph: vdash, bayreuth, dirk, sta, reaffirmed, tfl, wilmington, mathematician,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.0558 0.3144 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1264 0.3041 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.0366 0.3063 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.0294 0.3171 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.0932 0.3059 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.0643 0.3068 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.0785 0.3059 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.0260 0.3091 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.0373 0.3088 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.0702 0.3237 sec/batch
# Nearest to about: kastrioti, know, month, kfor, balding, arise, hiddenstructure, extractor,
# Nearest to one: six, seven, eight, two, nine, zero, three, five,
# Nearest to at: suffered, matzoh, rethink, continuing, contained, cottle, terming, hyundai,
# Nearest to more: bitrates, ambitious, gradually, metaphors, acceptable, basilides, emit, worthy,
# Nearest to history: npd, egypt, stanford, senayan, dao, external, schengen, pavel,
# Nearest to if: huck, requisite, tell, disconcerting, defined, befall, value, negative,
# Nearest to war: soviet, pershing, infantry, seize, moderate, homeowners, neutrality, norwegians,
# Nearest to had: before, grandson, ensured, martyr, retire, punishable, holding, merciful,
# Nearest to applied: usefulness, barristers, differs, manufactures, fraggle, originally, maps, standing,
# Nearest to assembly: representatives, malatesta, appoints, elections, senate, parliamentary, referendum, devolved,
# Nearest to troops: wounded, colonists, army, forces, were, invasion, roommates, commander,
# Nearest to engine: belgique, plugs, ntsc, combustion, clock, projective, handlers, marlow,
# Nearest to mean: vanishes, rabbi, modulo, brushing, mistresses, laugh, disestablishment, does,
# Nearest to existence: coincidences, duality, trump, attributed, pursuant, quartier, treated, maintaining,
# Nearest to magazine: devoted, strikeout, albicans, aphra, earning, fansite, vijayanagara, freelance,
# Nearest to joseph: bayreuth, vdash, dirk, sta, mathematician, tfl, nicholson, reaffirmed,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.0953 0.3449 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.0683 0.3072 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.0624 0.3087 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.0537 0.3121 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.0339 0.3107 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.0120 0.3067 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.0279 0.3082 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.0042 0.3094 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.0801 0.3112 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1052 0.3078 sec/batch
# Nearest to about: kastrioti, month, know, balding, kfor, emigration, amid, eustathius,
# Nearest to one: six, eight, seven, nine, two, three, zero, five,
# Nearest to at: suffered, continuing, years, rethink, matzoh, terming, contained, cottle,
# Nearest to more: bitrates, kasem, tahuantinsuyu, ambitious, worthy, acceptable, basilides, gradually,
# Nearest to history: npd, egypt, external, dao, stanford, senayan, follett, geographers,
# Nearest to if: huck, tell, requisite, prostrate, befall, rallying, disconcerting, value,
# Nearest to war: soviet, pershing, norwegians, infantry, gotlanders, seize, prisoners, silesia,
# Nearest to had: before, grandson, ensured, occasioned, insurmountable, martyr, merely, northerners,
# Nearest to applied: usefulness, barristers, manufactures, originally, differs, fraggle, maps, standing,
# Nearest to assembly: malatesta, representatives, parliamentary, appoints, elections, devolved, intensify, referendum,
# Nearest to troops: wounded, colonists, army, forces, were, invasion, roommates, landing,
# Nearest to engine: plugs, belgique, ntsc, engines, combustion, clock, piston, projective,
# Nearest to mean: vanishes, rabbi, mistresses, does, disestablishment, modulo, brushing, fasci,
# Nearest to existence: coincidences, duality, trump, pursuant, quartier, attributed, maintaining, ericales,
# Nearest to magazine: devoted, albicans, strikeout, freelance, aphra, fansite, earning, animator,
# Nearest to joseph: bayreuth, vdash, dirk, sta, stated, tfl, reaffirmed, wilmington,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.1202 0.3242 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.0478 0.3600 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 3.9911 0.3519 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.0422 0.3231 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 3.9125 0.3183 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.0236 0.2985 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.0402 0.2993 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 3.9885 0.2923 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.0572 0.0585 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 3.9648 0.3228 sec/batch
# Nearest to about: kastrioti, know, month, balding, kfor, emigration, eustathius, hemisphere,
# Nearest to one: eight, seven, two, six, nine, three, five, zero,
# Nearest to at: suffered, matzoh, rethink, continuing, years, hyundai, contained, cnd,
# Nearest to more: bitrates, ambitious, specifications, kasem, gradually, acceptable, tahuantinsuyu, basilides,
# Nearest to history: npd, senayan, external, stanford, egypt, schengen, pioneers, follett,
# Nearest to if: huck, tell, prostrate, requisite, negative, befall, value, rallying,
# Nearest to war: soviet, pershing, seize, norwegians, infantry, neutrality, prisoners, convoys,
# Nearest to had: ensured, grandson, before, insurmountable, holding, slipping, occasioned, retire,
# Nearest to applied: usefulness, barristers, manufactures, differs, originally, maps, fraggle, dft,
# Nearest to assembly: malatesta, representatives, appoints, parliamentary, senate, intensify, czi, elections,
# Nearest to troops: wounded, colonists, forces, army, invasion, roommates, were, congregate,
# Nearest to engine: plugs, ntsc, engines, belgique, combustion, piston, clock, powered,
# Nearest to mean: vanishes, rabbi, does, modulo, mistresses, disestablishment, brushing, variance,
# Nearest to existence: duality, coincidences, pursuant, trump, maintaining, quartier, attributed, maimonides,
# Nearest to magazine: devoted, albicans, strikeout, equates, freelance, prabhakaran, animator, fansite,
# Nearest to joseph: bayreuth, vdash, stated, sta, dirk, marcian, reaffirmed, rundstedt,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 3.9662 0.3276 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 3.9142 0.2986 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 3.9247 0.3043 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 3.9203 0.2946 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 3.9491 0.3028 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.8837 0.2995 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 3.9566 0.3042 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 3.9524 0.2882 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 3.9676 0.2954 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.8912 0.2938 sec/batch
# Nearest to about: kastrioti, know, month, kfor, balding, eustathius, hiddenstructure, arise,
# Nearest to one: eight, seven, six, two, nine, three, five, zero,
# Nearest to at: suffered, matzoh, continuing, years, rethink, contained, expanded, ankan,
# Nearest to more: bitrates, kasem, ambitious, gradually, sartor, specifications, acceptable, worthy,
# Nearest to history: npd, senayan, stanford, follett, external, pioneers, photos, schengen,
# Nearest to if: huck, befall, tell, prostrate, value, requisite, defined, negative,
# Nearest to war: soviet, pershing, seize, infantry, norwegians, convoys, neutrality, militia,
# Nearest to had: before, ensured, grandson, insurmountable, retire, burdensome, holding, merciful,
# Nearest to applied: usefulness, barristers, manufactures, differs, originally, maps, fraggle, dft,
# Nearest to assembly: malatesta, representatives, appoints, senate, parliamentary, intensify, quranic, czi,
# Nearest to troops: wounded, forces, colonists, army, were, invasion, roommates, congregate,
# Nearest to engine: engines, plugs, ntsc, belgique, combustion, piston, powered, clock,
# Nearest to mean: vanishes, rabbi, disestablishment, does, mistresses, modulo, variance, protium,
# Nearest to existence: coincidences, duality, maintaining, pursuant, attributed, trump, ericales, quartier,
# Nearest to magazine: devoted, albicans, strikeout, equates, animator, prabhakaran, freelance, fansite,
# Nearest to joseph: bayreuth, vdash, stated, sta, reaffirmed, marcian, dirk, guillain,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.8559 0.3016 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.8838 0.2926 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.8661 0.2885 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 3.9083 0.2895 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 3.9314 0.2909 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 3.9032 0.2985 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 3.9067 18.1521 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 3.9581 0.3100 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 3.9327 0.3168 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 3.9123 0.3411 sec/batch
# Nearest to about: kastrioti, know, month, kfor, emigration, arise, balding, eustathius,
# Nearest to one: eight, nine, two, seven, six, five, three, zero,
# Nearest to at: suffered, continuing, matzoh, rethink, years, hyundai, when, terming,
# Nearest to more: bitrates, acceptable, ambitious, specifications, gradually, etymological, replenish, diffracted,
# Nearest to history: npd, senayan, follett, external, stanford, photos, egypt, com,
# Nearest to if: huck, befall, tell, value, defined, requisite, inflicting, disconcerting,
# Nearest to war: soviet, pershing, neutrality, commandant, prisoners, infantry, seize, inspire,
# Nearest to had: before, grandson, ensured, insurmountable, retire, burdensome, occasioned, northerners,
# Nearest to applied: usefulness, barristers, manufactures, differs, originally, maps, fraggle, polarity,
# Nearest to assembly: appoints, representatives, malatesta, parliamentary, senate, referendum, elections, devolved,
# Nearest to troops: wounded, colonists, forces, army, invasion, were, roommates, commander,
# Nearest to engine: engines, plugs, ntsc, combustion, piston, belgique, powered, automobiles,
# Nearest to mean: vanishes, rabbi, disestablishment, does, mistresses, fasci, ef, bouzouki,
# Nearest to existence: coincidences, duality, maintaining, extraordinary, trump, pursuant, function, ericales,
# Nearest to magazine: devoted, strikeout, freelance, albicans, fansite, prabhakaran, animator, aphra,
# Nearest to joseph: bayreuth, vdash, stated, marcian, guillain, mathematician, reaffirmed, dirk,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 3.9149 0.3352 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 3.9358 0.3214 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 3.9161 0.3238 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 3.9054 0.3782 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 3.9269 0.3463 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 3.8955 0.3208 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 3.9343 0.3267 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 3.9055 0.3074 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 3.9544 0.2925 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 3.9092 0.2933 sec/batch
# Nearest to about: kastrioti, know, month, arise, balding, emigration, kfor, hemisphere,
# Nearest to one: eight, seven, nine, two, six, three, zero, four,
# Nearest to at: suffered, continuing, matzoh, when, years, hyundai, rethink, contained,
# Nearest to more: bitrates, specifications, ambitious, basilides, worthy, acceptable, emit, diffracted,
# Nearest to history: follett, senayan, npd, external, egypt, culture, stanford, geographers,
# Nearest to if: huck, befall, inflicting, tell, requisite, will, disconcerting, prostrate,
# Nearest to war: soviet, pershing, neutrality, norwegians, wars, militia, convoys, prisoners,
# Nearest to had: before, ensured, grandson, retire, insurmountable, northerners, burdensome, occasioned,
# Nearest to applied: usefulness, barristers, manufactures, differs, originally, fraggle, maps, polarity,
# Nearest to assembly: appoints, malatesta, parliamentary, representatives, senate, unicameral, devolved, intensify,
# Nearest to troops: wounded, forces, army, colonists, invasion, were, roommates, congregate,
# Nearest to engine: engines, plugs, ntsc, combustion, projective, belgique, piston, powered,
# Nearest to mean: vanishes, rabbi, disestablishment, fasci, mistresses, ef, does, bouzouki,
# Nearest to existence: coincidences, duality, trump, extraordinary, maintaining, attributed, quartier, ericales,
# Nearest to magazine: devoted, freelance, strikeout, prabhakaran, albicans, fansite, animator, mods,
# Nearest to joseph: bayreuth, vdash, stated, marcian, dirk, mathematician, guillain, sebald,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 3.8886 0.3014 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.8883 0.2966 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.9024 0.3246 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 3.8888 0.3330 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 3.8936 0.3224 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 3.9804 0.3055 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0011 0.2901 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 3.9071 0.2945 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.8770 0.2955 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 3.9030 0.2967 sec/batch
# Nearest to about: kastrioti, know, month, balding, emigration, dommel, hemisphere, kfor,
# Nearest to one: eight, nine, seven, two, six, three, zero, four,
# Nearest to at: suffered, matzoh, continuing, when, years, hyundai, mausoleum, contained,
# Nearest to more: bitrates, specifications, ambitious, acceptable, kasem, gradually, basilides, regimes,
# Nearest to history: senayan, follett, npd, external, photos, schengen, com, pioneers,
# Nearest to if: huck, befall, prostrate, tell, requisite, inflicting, haar, negative,
# Nearest to war: soviet, pershing, norwegians, prisoners, convoys, militia, neutrality, commandant,
# Nearest to had: before, ensured, grandson, insurmountable, retire, holding, centrosomes, restitution,
# Nearest to applied: usefulness, barristers, manufactures, differs, originally, fraggle, maps, polarity,
# Nearest to assembly: parliamentary, representatives, appoints, malatesta, devolved, consists, senate, czi,
# Nearest to troops: wounded, forces, colonists, army, invasion, roommates, usta, brindle,
# Nearest to engine: engines, combustion, plugs, ntsc, piston, powered, belgique, projective,
# Nearest to mean: vanishes, rabbi, disestablishment, mistresses, fasci, does, ef, slows,
# Nearest to existence: coincidences, duality, trump, extraordinary, maintaining, furtherance, quartier, pursuant,
# Nearest to magazine: devoted, strikeout, freelance, prabhakaran, albicans, aphra, fansite, animator,
# Nearest to joseph: bayreuth, vdash, stated, mathematician, dirk, marcian, sta, guillain,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.8172 0.3097 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.8428 0.2946 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 3.8792 0.2939 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.8646 0.3121 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 3.9256 18.1372 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 3.8568 0.2953 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.8732 0.2948 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.8079 0.2911 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.8246 0.3181 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.8022 0.3210 sec/batch
# Nearest to about: kastrioti, month, know, emigration, balding, hiddenstructure, hemisphere, dommel,
# Nearest to one: eight, seven, nine, two, six, three, five, zero,
# Nearest to at: matzoh, continuing, suffered, hyundai, when, years, mausoleum, ankan,
# Nearest to more: bitrates, acceptable, gradually, worthy, ambitious, specifications, emit, metaphors,
# Nearest to history: senayan, follett, npd, photos, external, stanford, geographers, schengen,
# Nearest to if: huck, prostrate, befall, tell, inflicting, get, prosecutor, requisite,
# Nearest to war: soviet, pershing, convoys, neutrality, norwegians, prisoners, inspire, tricity,
# Nearest to had: before, ensured, grandson, insurmountable, retire, restitution, occasioned, burdensome,
# Nearest to applied: usefulness, barristers, manufactures, differs, polarity, originally, maps, standing,
# Nearest to assembly: appoints, parliamentary, representatives, malatesta, consists, devolved, intensify, czi,
# Nearest to troops: forces, wounded, colonists, army, roommates, invasion, usta, were,
# Nearest to engine: engines, combustion, plugs, ntsc, powered, belgique, piston, projective,
# Nearest to mean: vanishes, rabbi, disestablishment, fasci, ef, mistresses, variance, gendered,
# Nearest to existence: coincidences, duality, trump, extraordinary, furtherance, maintaining, quartier, attributed,
# Nearest to magazine: devoted, strikeout, prabhakaran, freelance, mods, albicans, animator, toxicology,
# Nearest to joseph: bayreuth, vdash, stated, marcian, mathematician, sta, dirk, rundstedt,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.8357 0.3289 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.7800 0.3295 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.8436 0.3190 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.8702 0.3227 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.8433 0.3213 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.8442 0.3257 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.7086 0.3288 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.8118 0.3317 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.7462 0.3321 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.8029 0.3267 sec/batch
# Nearest to about: know, kastrioti, month, zero, emigration, dommel, kfor, servicemales,
# Nearest to one: two, eight, seven, nine, six, three, five, zero,
# Nearest to at: suffered, hyundai, continuing, matzoh, when, five, ankan, years,
# Nearest to more: bitrates, emit, diffracted, acceptable, gradually, regimes, worthy, randomization,
# Nearest to history: senayan, follett, npd, external, stanford, photos, com, geographers,
# Nearest to if: huck, befall, tell, inflicting, gaited, prostrate, haar, satisfies,
# Nearest to war: soviet, pershing, convoys, neutrality, prisoners, tricity, norwegians, inspire,
# Nearest to had: before, ensured, grandson, retire, insurmountable, northerners, holding, burdensome,
# Nearest to applied: barristers, usefulness, manufactures, polarity, differs, maps, originally, standing,
# Nearest to assembly: representatives, parliamentary, appoints, malatesta, consists, senate, devolved, czi,
# Nearest to troops: forces, wounded, colonists, army, roommates, invasion, congregate, usta,
# Nearest to engine: engines, plugs, combustion, ntsc, projective, piston, powered, belgique,
# Nearest to mean: vanishes, rabbi, disestablishment, fasci, ef, half, mistresses, variance,
# Nearest to existence: coincidences, duality, trump, extraordinary, maintaining, furtherance, ericales, attributed,
# Nearest to magazine: devoted, prabhakaran, strikeout, mods, albicans, freelance, animator, fansite,
# Nearest to joseph: bayreuth, vdash, stated, marcian, guillain, sta, reaffirmed, sebald,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.8459 0.3425 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.8289 0.3368 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.7750 0.3339 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.8539 0.3387 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.8848 0.3409 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.7640 0.3339 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.8315 0.3460 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.8119 0.3596 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.8204 0.3416 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.7945 0.3421 sec/batch
# Nearest to about: know, kastrioti, month, emigration, dommel, zero, servicemales, kfor,
# Nearest to one: eight, nine, two, seven, six, three, five, four,
# Nearest to at: suffered, hyundai, continuing, when, heechee, matzoh, years, attended,
# Nearest to more: ambitious, bitrates, acceptable, worthy, emit, halving, specifications, basilides,
# Nearest to history: senayan, follett, npd, stanford, external, of, historical, pioneers,
# Nearest to if: huck, befall, tell, haar, will, satisfies, inflicting, prostrate,
# Nearest to war: soviet, pershing, convoys, inspire, tricity, neutrality, prisoners, norwegians,
# Nearest to had: before, ensured, northerners, retire, insurmountable, grandson, liking, rooftop,
# Nearest to applied: barristers, usefulness, manufactures, differs, originally, fraggle, maps, polarity,
# Nearest to assembly: appoints, representatives, parliamentary, malatesta, czi, unicameral, devolved, senate,
# Nearest to troops: forces, wounded, colonists, army, invasion, roommates, usta, congregate,
# Nearest to engine: engines, combustion, plugs, projective, belgique, ntsc, piston, powered,
# Nearest to mean: vanishes, rabbi, disestablishment, mistresses, fasci, pineal, semitones, ef,
# Nearest to existence: coincidences, duality, trump, extraordinary, furtherance, maintaining, irrevocable, pursuant,
# Nearest to magazine: devoted, prabhakaran, strikeout, freelance, mods, harper, fansite, albicans,
# Nearest to joseph: bayreuth, vdash, stated, guillain, marcian, mathematician, kearns, rundstedt,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.8541 0.3587 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.8379 0.3450 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.8015 0.3438 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.8302 0.3425 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.8365 0.3452 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.8476 0.3409 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.7986 0.3532 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.7935 0.3491 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.8132 0.3435 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.8349 0.3466 sec/batch
# Nearest to about: kastrioti, know, month, zero, dommel, emigration, servicemales, kfor,
# Nearest to one: eight, nine, seven, two, six, three, zero, five,
# Nearest to at: continuing, hyundai, when, attended, suffered, mausoleum, contained, years,
# Nearest to more: specifications, seats, ambitious, acceptable, bitrates, halving, solicits, regimes,
# Nearest to history: follett, senayan, of, npd, photos, external, stanford, europe,
# Nearest to if: huck, befall, tell, prostrate, get, inflicting, will, hardens,
# Nearest to war: soviet, pershing, convoys, neutrality, prisoners, wars, tricity, imperialist,
# Nearest to had: before, ensured, northerners, grandson, guarantor, insurmountable, nihon, retire,
# Nearest to applied: barristers, manufactures, usefulness, originally, differs, polarity, fraggle, standing,
# ...
# Nearest to assembly: representatives, unicameral, devolved, appoints, malatesta, elected, udi, tsai,
# Nearest to troops: forces, permitting, invasion, army, usta, roommates, wounded, colonists,
# Nearest to engine: engines, combustion, piston, supercar, plugs, engined, powered, interactivity,
# Nearest to mean: thysanoessa, vanishes, pineal, suing, cielo, savanna, fasci, disestablishment,
# Nearest to existence: coincidences, extraordinary, duality, trump, furtherance, creationist, jagdish, camira,
# Nearest to magazine: devoted, harper, magazines, prabhakaran, toxicology, monthly, arborway, edd,
# Nearest to joseph: vdash, stated, rundstedt, goldberg, guillain, bayreuth, sebald, jesus,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.6012 0.3774 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.6385 0.3789 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.6217 0.3604 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.6293 0.3587 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.6026 0.3622 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.6583 0.3629 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.6457 0.4464 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.6122 0.3936 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.6566 0.4193 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.6155 0.3989 sec/batch
# Nearest to about: zero, servicemales, three, mm, dommel, five, much, wavefunction,
# Nearest to one: nine, eight, two, three, seven, six, five, four,
# Nearest to at: attended, hyundai, five, rhazes, from, when, commenced, matzoh,
# Nearest to more: seats, halving, basilides, computationally, solicits, supersonic, exaggeration, acceptable,
# Nearest to history: of, historical, follett, com, external, list, timeline, links,
# Nearest to if: befall, prostrate, get, can, disheveled, i, haar, follows,
# Nearest to war: wars, neutrality, soviet, selwyn, bacchae, pershing, imperialist, convoys,
# Nearest to had: before, was, gemellus, having, were, guarantor, lyons, homininae,
# Nearest to applied: barristers, sciences, resistive, polarity, cardozo, manufactures, perverse, discontinuity,
# Nearest to assembly: representatives, unicameral, devolved, appoints, ials, malatesta, tsai, elected,
# Nearest to troops: forces, invasion, army, permitting, roommates, usta, colonists, brindle,
# Nearest to engine: engines, combustion, piston, plugs, interactivity, supercar, notables, engined,
# Nearest to mean: thysanoessa, vanishes, pineal, suing, ef, fasci, cielo, savanna,
# Nearest to existence: coincidences, duality, extraordinary, furtherance, trump, creationist, jagdish, goran,
# Nearest to magazine: devoted, harper, magazines, prabhakaran, monthly, toxicology, arborway, edd,
# Nearest to joseph: vdash, stated, rundstedt, bayreuth, guillain, sebald, crackers, juana,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.6428 0.4036 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.6115 0.4179 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.6301 0.4332 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.6161 0.3203 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.6862 0.3061 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.5966 0.3029 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.7643 0.3054 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.6968 0.3042 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.6756 0.3014 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.5887 0.3034 sec/batch
# Nearest to about: zero, servicemales, mm, three, dommel, five, injures, much,
# Nearest to one: nine, eight, two, three, seven, six, four, five,
# Nearest to at: attended, hyundai, five, when, rhazes, from, mausoleum, where,
# Nearest to more: seats, halving, afram, incremental, supersonic, exaggeration, solicits, balance,
# Nearest to history: of, historical, follett, com, timeline, senayan, external, historiography,
# Nearest to if: befall, prostrate, disheveled, gaited, tell, get, i, follows,
# Nearest to war: wars, neutrality, soviet, bacchae, selwyn, pershing, tricity, creation,
# Nearest to had: before, was, were, homininae, worked, gemellus, guarantor, romantically,
# Nearest to applied: barristers, sciences, resistive, polarity, manufactures, cardozo, perverse, discontinuity,
# Nearest to assembly: representatives, unicameral, appoints, devolved, elected, tsai, parliamentary, ials,
# Nearest to troops: forces, invasion, permitting, army, colonists, roommates, usta, isolation,
# Nearest to engine: engines, combustion, plugs, piston, interactivity, supercar, notables, engined,
# Nearest to mean: thysanoessa, vanishes, pineal, suing, cielo, ef, fasci, smoother,
# Nearest to existence: coincidences, extraordinary, duality, furtherance, creationist, trump, jagdish, goran,
# Nearest to magazine: harper, devoted, magazines, prabhakaran, monthly, toxicology, arborway, freelance,
# Nearest to joseph: vdash, stated, rundstedt, guillain, crackers, bayreuth, juana, goldberg,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.5646 0.3099 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.6396 0.3105 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.5274 0.3139 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.6529 0.3023 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.6185 0.3048 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.6192 0.3139 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.6694 0.1800 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.5884 0.3620 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.6088 0.3467 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.5884 0.3337 sec/batch
# Nearest to about: zero, three, servicemales, mm, dommel, much, wavefunction, five,
# Nearest to one: eight, nine, two, three, seven, six, five, four,
# Nearest to at: attended, from, hyundai, when, where, rhazes, five, the,
# Nearest to more: halving, exaggeration, incremental, seats, supersonic, acceptable, solicits, much,
# Nearest to history: historical, follett, of, com, timeline, senayan, external, graphein,
# Nearest to if: befall, disheveled, prostrate, get, gaited, can, tell, haar,
# Nearest to war: wars, neutrality, soviet, bacchae, tricity, projekt, joshi, convoys,
# Nearest to had: was, before, were, gemellus, worked, marcion, lyons, having,
# Nearest to applied: barristers, sciences, cardozo, manufactures, polarity, resistive, perverse, terms,
# Nearest to assembly: representatives, unicameral, devolved, appoints, tsai, ials, elected, encapsulates,
# Nearest to troops: forces, invasion, army, colonists, roommates, permitting, usta, brindle,
# Nearest to engine: engines, combustion, plugs, interactivity, piston, supercar, gearbox, notables,
# Nearest to mean: thysanoessa, cielo, suing, vanishes, ef, pineal, fasci, half,
# Nearest to existence: coincidences, duality, extraordinary, creationist, furtherance, trump, jagdish, goran,
# Nearest to magazine: magazines, devoted, harper, prabhakaran, monthly, toxicology, popular, freelance,
# Nearest to joseph: vdash, rundstedt, crackers, guillain, bayreuth, goldberg, stated, juana,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.5941 18.1195 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.5847 0.3005 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.5912 4.5996 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.5643 0.3122 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.6411 0.3119 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.6359 0.3063 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.6418 0.3420 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.4904 0.3501 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.5683 0.3963 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.5735 0.3515 sec/batch
# Nearest to about: zero, three, dommel, mm, servicemales, five, billion, wavefunction,
# Nearest to one: eight, two, nine, three, seven, six, five, four,
# Nearest to at: attended, hyundai, five, rhazes, when, from, commenced, continuing,
# Nearest to more: halving, seats, incremental, distinguishing, problem, much, exaggeration, acceptable,
# Nearest to history: historical, of, com, follett, senayan, external, list, timeline,
# Nearest to if: befall, can, haar, follows, gaited, tell, disheveled, that,
# Nearest to war: wars, neutrality, soviet, pershing, tricity, implications, kennan, projekt,
# Nearest to had: before, was, gemellus, were, homininae, worked, paperwork, sehul,
# Nearest to applied: barristers, sciences, resistive, manufactures, cardozo, polarity, detonators, innovate,
# Nearest to assembly: representatives, unicameral, devolved, appoints, ials, udi, tsai, elected,
# Nearest to troops: forces, invasion, army, permitting, usta, influence, roommates, colonists,
# Nearest to engine: engines, combustion, plugs, interactivity, notables, piston, supercar, gearbox,
# Nearest to mean: thysanoessa, cielo, suing, vanishes, ef, pineal, savanna, half,
# Nearest to existence: coincidences, extraordinary, duality, creationist, trump, furtherance, jagdish, goran,
# Nearest to magazine: devoted, magazines, harper, prabhakaran, monthly, toxicology, edd, arborway,
# Nearest to joseph: vdash, stated, jesus, mormonism, rundstedt, goldberg, guillain, bayreuth,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.5229 0.3604 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.5751 0.3498 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.6085 0.3730 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.5992 0.3601 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.5897 0.3607 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.6555 0.3616 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.6012 0.3670 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.5842 0.3720 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.6212 0.3715 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.5991 0.3607 sec/batch
# Nearest to about: zero, three, dommel, mm, servicemales, five, much, dash,
# Nearest to one: eight, nine, two, three, seven, six, four, five,
# Nearest to at: attended, hyundai, rhazes, a, five, of, when, where,
# Nearest to more: halving, exaggeration, seats, incremental, balance, distinguishing, acceptable, computationally,
# Nearest to history: of, historical, follett, com, list, external, senayan, timeline,
# Nearest to if: befall, disheveled, that, can, arbitron, get, be, plums,
# Nearest to war: neutrality, wars, soviet, pershing, implications, kennan, bacchae, convoys,
# Nearest to had: was, before, gemellus, were, barks, halos, worked, paperwork,
# Nearest to applied: barristers, sciences, resistive, cardozo, manufactures, terms, polarity, innovate,
# Nearest to assembly: representatives, unicameral, appoints, devolved, ials, tsai, elected, tracker,
# Nearest to troops: forces, invasion, army, permitting, colonists, roommates, usta, brindle,
# Nearest to engine: engines, combustion, plugs, piston, interactivity, gearbox, notables, clutches,
# Nearest to mean: thysanoessa, suing, cielo, pineal, ef, vanishes, egregious, savanna,
# Nearest to existence: coincidences, extraordinary, duality, trump, creationist, furtherance, jagdish, sustain,
# Nearest to magazine: devoted, magazines, harper, prabhakaran, monthly, toxicology, edd, arborway,
# Nearest to joseph: vdash, goldberg, bayreuth, rundstedt, stated, guillain, mormonism, sceptre,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.6106 0.3794 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.5896 0.3676 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.5700 0.3557 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.6125 0.3633 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.6390 0.3622 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.6131 0.3536 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.5889 0.3465 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.6225 0.3521 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.5881 0.3493 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.5949 0.3517 sec/batch
# Nearest to about: zero, three, five, servicemales, dommel, much, mm, complicate,
# Nearest to one: eight, nine, two, three, seven, six, four, five,
# Nearest to at: attended, five, hyundai, rhazes, when, zero, a, from,
# Nearest to more: seats, halving, incremental, much, exaggeration, acceptable, balance, need,
# Nearest to history: of, historical, com, follett, timeline, external, list, see,
# Nearest to if: befall, can, follows, i, get, tell, be, that,
# Nearest to war: wars, neutrality, soviet, pershing, implications, creation, bacchae, selfishness,
# Nearest to had: before, was, gemellus, having, were, finally, with, halos,
# Nearest to applied: barristers, sciences, resistive, cardozo, manufactures, terms, perverse, polarity,
# Nearest to assembly: representatives, unicameral, appoints, devolved, ials, tsai, tracker, elected,
# Nearest to troops: forces, invasion, permitting, army, usta, colonists, roommates, awareness,
# Nearest to engine: engines, combustion, interactivity, plugs, piston, gearbox, clutches, supercar,
# Nearest to mean: thysanoessa, suing, pineal, cielo, smoother, fasci, savanna, ef,
# Nearest to existence: coincidences, extraordinary, duality, trump, creationist, furtherance, jagdish, endeavor,
# Nearest to magazine: devoted, harper, magazines, prabhakaran, monthly, toxicology, edd, arborway,
# Nearest to joseph: vdash, crackers, rundstedt, bayreuth, goldberg, stated, guillain, psychoanalyst,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.6488 0.3682 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.5052 0.3585 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.6812 0.3563 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.6795 0.3562 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.6441 0.3545 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.5932 0.3539 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.5548 0.3496 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.5961 0.3565 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.5202 0.3545 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.6304 0.3463 sec/batch
# Nearest to about: three, zero, much, dommel, extractor, mm, billion, servicemales,
# Nearest to one: eight, nine, seven, three, two, six, four, five,
# Nearest to at: attended, hyundai, rhazes, five, when, from, where, hijjah,
# Nearest to more: halving, seats, exaggeration, incremental, problem, need, much, balance,
# Nearest to history: of, historical, com, follett, timeline, external, links, senayan,
# Nearest to if: befall, can, get, arbitron, follows, haar, be, tell,
# Nearest to war: wars, soviet, neutrality, pershing, bacchae, implications, convoys, aroostook,
# Nearest to had: was, before, were, worked, gemellus, halos, marcion, lyons,
# Nearest to applied: barristers, sciences, resistive, terms, polarity, cardozo, discontinuity, manufactures,
# Nearest to assembly: representatives, unicameral, tsai, appoints, ials, devolved, tracker, elected,
# Nearest to troops: forces, invasion, army, permitting, usta, colonists, roommates, brindle,
# Nearest to engine: engines, combustion, interactivity, plugs, gearbox, notables, supercar, mpg,
# Nearest to mean: thysanoessa, pineal, suing, smoother, cielo, ef, egregious, vanishes,
# Nearest to existence: coincidences, extraordinary, duality, creationist, furtherance, trump, sustain, jagdish,
# Nearest to magazine: devoted, harper, magazines, prabhakaran, monthly, toxicology, edd, popular,
# Nearest to joseph: mormonism, bayreuth, vdash, psychoanalyst, crackers, county, rundstedt, guillain,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.5918 0.3610 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.5835 0.3544 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-153-4eeca6a379f0> in <module>()
#       3
#       4 with tf.Session(graph=train_graph) as sess:
# ----> 5     saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
#       6     embed_mat = sess.run(embedding)
#
# /Users/michalczapski/anaconda/envs/dlnd-tf-lab/lib/python3.5/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1555       return
#    1556     if save_path is None:
# -> 1557       raise ValueError("Can't load save_path when it is None.")
#    1558     logging.info("Restoring parameters from %s", save_path)
#    1559     sess.run(self.saver_def.restore_op_name,
#
# ValueError: Can't load save_path when it is None.

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
