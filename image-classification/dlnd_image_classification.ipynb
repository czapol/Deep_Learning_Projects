# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 2
sample_id = 19
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 19:
# Image - Min Value: 3 Max Value: 245
# Image - Shape: (32, 32, 3)
# Label - Label Id: 6 Name: frog

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function

    scale_max,scale_min=255,0
    x_prim=(x-scale_min)/(scale_max-scale_min)
    return x_prim


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    
    ##list of labels [2,5,1,9,8,7,3,1] = [0,0,0,1,0,0,0,0]
    
    onehot=np.zeros((len(x),10))
    for i in range(len(x)):
        onehot[i,x[i]]=1
        
    
    return onehot


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf


def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    shape=list(image_shape)
    shape.insert(0,None)
    # TODO: Implement Function    
    return tf.placeholder(tf.float32, shape, "x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    label_input=tf.placeholder(tf.float32, [None,n_classes],"y")
    return label_input


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    keep_prob=tf.placeholder(tf.float32,name="keep_prob")
    return keep_prob


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    x_dim = x_tensor.get_shape().as_list()
    #weights
    shape=list(conv_ksize+(x_dim[-1],)+(conv_num_outputs,))
    weights=tf.Variable(tf.truncated_normal(shape,0,0.1))
                        
    #bias
    biases=tf.Variable(tf.zeros(conv_num_outputs))
    
    #convolution
    strides=list((1,)+conv_strides+(1,)) # changing into shape [1,strides,strides,1]
    conv=tf.nn.conv2d(x_tensor,weights,strides,padding='SAME')
    conv=tf.nn.bias_add(conv,biases)
    conv=tf.nn.relu(conv)
    #pool
    pstrides=list((1,)+pool_strides+(1,)) # changing into shape [1,strides,strides,1]
    pksize=list((1,)+pool_ksize+(1,)) # changing into shape [1,k,k,1]
  
    convpool=tf.nn.max_pool(conv,pksize,pstrides,padding="SAME")
    # TODO: Implement Function
    return convpool


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    
    
    
  
    # TODO:
    
    x_dim = x_tensor.get_shape().as_list() 
    
    
    return tf.reshape(x_tensor,[-1,x_dim[1]*x_dim[2]*x_dim[3]])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    '''
    x_dim=x_tensor.get_shape().as_list()
    shape=[x_dim[1]]+[num_outputs]
    #weights
    weights=tf.Variable(tf.truncated_normal(shape,0,0.1))
    #bias
    biases=tf.Variable(tf.zeros(num_outputs))
    #output
    fc1=tf.add(tf.matmul(x_tensor,weights),biases)
    #activation
    fc1=tf.nn.relu(fc1)
    '''
    # TODO: Implement Function
    return tf.nn.relu(output(x_tensor,num_outputs))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    
    x_dim=x_tensor.get_shape().as_list()
    shape=[x_dim[1]]+[num_outputs]
    #weights
    weights=tf.Variable(tf.truncated_normal(shape,0,0.1))
    #bias
    biases=tf.Variable(tf.zeros(num_outputs))
    #output
    out=tf.add(tf.matmul(x_tensor,weights),biases)

    
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    model=conv2d_maxpool(x, conv_num_outputs=20, conv_ksize=(4,4), conv_strides=(2,2), pool_ksize=(2,2), pool_strides=(2,2))
    model=conv2d_maxpool(x, conv_num_outputs=14, conv_ksize=(2,2), conv_strides=(1,1), pool_ksize=(4,4), pool_strides=(2,2))
    #model=conv2d_maxpool(x, conv_num_outputs=30, conv_ksize=(1,1), conv_strides=(4,4), pool_ksize=(1,1), pool_strides=(1,1))

    #model=tf.nn.dropout(model,keep_prob)


    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    model=flatten(model)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    model=fully_conn(model, num_outputs=300)
    #model=tf.nn.dropout(model,keep_prob)
    model=fully_conn(model, num_outputs=100)
    #model=fully_conn(model, num_outputs=50)
    model=tf.nn.dropout(model,keep_prob)

    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #dropout:
    
    model=output(model, num_outputs=10)
    
    
    
    # TODO: return output
    return model


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer,feed_dict={x:feature_batch, y:label_batch, keep_prob:keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    #loss:   
    
    loss = session.run(cost, feed_dict={x:feature_batch, y:label_batch, keep_prob:1.0})
    
    #accuracy:
    
    valid_acc=session.run(accuracy,feed_dict={x:valid_features, y:valid_labels, keep_prob:1.0})
    print('Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(
                loss,
                valid_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 50
batch_size = 512
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.0933 Validation Accuracy: 0.261000
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.9367 Validation Accuracy: 0.353000
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.7986 Validation Accuracy: 0.397800
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.6848 Validation Accuracy: 0.421800
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.6090 Validation Accuracy: 0.441200
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.5305 Validation Accuracy: 0.453800
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.4658 Validation Accuracy: 0.480000
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.4056 Validation Accuracy: 0.488000
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.3662 Validation Accuracy: 0.491800
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.3471 Validation Accuracy: 0.490600
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.2716 Validation Accuracy: 0.514800
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.2352 Validation Accuracy: 0.520800
# Epoch 13, CIFAR-10 Batch 1:  Loss:     1.1927 Validation Accuracy: 0.529600
# Epoch 14, CIFAR-10 Batch 1:  Loss:     1.1581 Validation Accuracy: 0.533600
# Epoch 15, CIFAR-10 Batch 1:  Loss:     1.1149 Validation Accuracy: 0.538200
# Epoch 16, CIFAR-10 Batch 1:  Loss:     1.0781 Validation Accuracy: 0.544800
# Epoch 17, CIFAR-10 Batch 1:  Loss:     1.0506 Validation Accuracy: 0.540600
# Epoch 18, CIFAR-10 Batch 1:  Loss:     1.0430 Validation Accuracy: 0.545800
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.9921 Validation Accuracy: 0.555200
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.9744 Validation Accuracy: 0.559200
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.9514 Validation Accuracy: 0.557200
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.9180 Validation Accuracy: 0.560800
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.8915 Validation Accuracy: 0.562200
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.8795 Validation Accuracy: 0.560800
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.8404 Validation Accuracy: 0.560200
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.8285 Validation Accuracy: 0.560600
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.8022 Validation Accuracy: 0.571800
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.7779 Validation Accuracy: 0.571400
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.7663 Validation Accuracy: 0.569000
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.7308 Validation Accuracy: 0.571200
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.7043 Validation Accuracy: 0.571400
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.7009 Validation Accuracy: 0.576800
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.6826 Validation Accuracy: 0.566600
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.6547 Validation Accuracy: 0.573000
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.6415 Validation Accuracy: 0.566200
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.6300 Validation Accuracy: 0.569200
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.5943 Validation Accuracy: 0.572400
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.5730 Validation Accuracy: 0.576600
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.5616 Validation Accuracy: 0.571400
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.5632 Validation Accuracy: 0.567400
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.5880 Validation Accuracy: 0.550000
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.5528 Validation Accuracy: 0.562800
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.5106 Validation Accuracy: 0.564000
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.4712 Validation Accuracy: 0.572400
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.4430 Validation Accuracy: 0.586200
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.4233 Validation Accuracy: 0.576000
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.4105 Validation Accuracy: 0.573400
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.4145 Validation Accuracy: 0.565200
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.3910 Validation Accuracy: 0.572200
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.3510 Validation Accuracy: 0.572400

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.2206 Validation Accuracy: 0.239600
# Epoch  1, CIFAR-10 Batch 2:  Loss:     2.0302 Validation Accuracy: 0.296400
# Epoch  1, CIFAR-10 Batch 3:  Loss:     1.9249 Validation Accuracy: 0.328400
# Epoch  1, CIFAR-10 Batch 4:  Loss:     1.7592 Validation Accuracy: 0.374800
# Epoch  1, CIFAR-10 Batch 5:  Loss:     1.7621 Validation Accuracy: 0.391400
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.7635 Validation Accuracy: 0.417800
# Epoch  2, CIFAR-10 Batch 2:  Loss:     1.6200 Validation Accuracy: 0.441000
# Epoch  2, CIFAR-10 Batch 3:  Loss:     1.5123 Validation Accuracy: 0.440400
# Epoch  2, CIFAR-10 Batch 4:  Loss:     1.4872 Validation Accuracy: 0.460200
# Epoch  2, CIFAR-10 Batch 5:  Loss:     1.5219 Validation Accuracy: 0.478200
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.5788 Validation Accuracy: 0.480400
# Epoch  3, CIFAR-10 Batch 2:  Loss:     1.4418 Validation Accuracy: 0.490800
# Epoch  3, CIFAR-10 Batch 3:  Loss:     1.3541 Validation Accuracy: 0.483400
# Epoch  3, CIFAR-10 Batch 4:  Loss:     1.3339 Validation Accuracy: 0.505600
# Epoch  3, CIFAR-10 Batch 5:  Loss:     1.4015 Validation Accuracy: 0.508200
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.4452 Validation Accuracy: 0.506400
# Epoch  4, CIFAR-10 Batch 2:  Loss:     1.3168 Validation Accuracy: 0.522200
# Epoch  4, CIFAR-10 Batch 3:  Loss:     1.2430 Validation Accuracy: 0.520200
# Epoch  4, CIFAR-10 Batch 4:  Loss:     1.2168 Validation Accuracy: 0.540400
# Epoch  4, CIFAR-10 Batch 5:  Loss:     1.2913 Validation Accuracy: 0.531600
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.3633 Validation Accuracy: 0.541200
# Epoch  5, CIFAR-10 Batch 2:  Loss:     1.2375 Validation Accuracy: 0.520800
# Epoch  5, CIFAR-10 Batch 3:  Loss:     1.1662 Validation Accuracy: 0.539800
# Epoch  5, CIFAR-10 Batch 4:  Loss:     1.1692 Validation Accuracy: 0.528400
# Epoch  5, CIFAR-10 Batch 5:  Loss:     1.2193 Validation Accuracy: 0.549000
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.3045 Validation Accuracy: 0.551000
# Epoch  6, CIFAR-10 Batch 2:  Loss:     1.1846 Validation Accuracy: 0.552000
# Epoch  6, CIFAR-10 Batch 3:  Loss:     1.0851 Validation Accuracy: 0.555600
# Epoch  6, CIFAR-10 Batch 4:  Loss:     1.0941 Validation Accuracy: 0.566200
# Epoch  6, CIFAR-10 Batch 5:  Loss:     1.1491 Validation Accuracy: 0.566200
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.2528 Validation Accuracy: 0.564200
# Epoch  7, CIFAR-10 Batch 2:  Loss:     1.1409 Validation Accuracy: 0.564600
# Epoch  7, CIFAR-10 Batch 3:  Loss:     1.0464 Validation Accuracy: 0.570200
# Epoch  7, CIFAR-10 Batch 4:  Loss:     1.0610 Validation Accuracy: 0.578200
# Epoch  7, CIFAR-10 Batch 5:  Loss:     1.0938 Validation Accuracy: 0.577400
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.2154 Validation Accuracy: 0.569800
# Epoch  8, CIFAR-10 Batch 2:  Loss:     1.0755 Validation Accuracy: 0.580800
# Epoch  8, CIFAR-10 Batch 3:  Loss:     0.9848 Validation Accuracy: 0.579200
# Epoch  8, CIFAR-10 Batch 4:  Loss:     1.0382 Validation Accuracy: 0.576000
# Epoch  8, CIFAR-10 Batch 5:  Loss:     1.0520 Validation Accuracy: 0.590600
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.1702 Validation Accuracy: 0.588800
# Epoch  9, CIFAR-10 Batch 2:  Loss:     1.0483 Validation Accuracy: 0.586000
# Epoch  9, CIFAR-10 Batch 3:  Loss:     0.9509 Validation Accuracy: 0.591400
# Epoch  9, CIFAR-10 Batch 4:  Loss:     0.9790 Validation Accuracy: 0.597400
# Epoch  9, CIFAR-10 Batch 5:  Loss:     0.9979 Validation Accuracy: 0.602600
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.1230 Validation Accuracy: 0.598200
# Epoch 10, CIFAR-10 Batch 2:  Loss:     1.0067 Validation Accuracy: 0.594400
# Epoch 10, CIFAR-10 Batch 3:  Loss:     0.9087 Validation Accuracy: 0.590400
# Epoch 10, CIFAR-10 Batch 4:  Loss:     0.9642 Validation Accuracy: 0.595800
# Epoch 10, CIFAR-10 Batch 5:  Loss:     0.9553 Validation Accuracy: 0.602400
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.0905 Validation Accuracy: 0.601400
# Epoch 11, CIFAR-10 Batch 2:  Loss:     0.9621 Validation Accuracy: 0.599800
# Epoch 11, CIFAR-10 Batch 3:  Loss:     0.8430 Validation Accuracy: 0.610400
# Epoch 11, CIFAR-10 Batch 4:  Loss:     0.9088 Validation Accuracy: 0.608800
# Epoch 11, CIFAR-10 Batch 5:  Loss:     0.8943 Validation Accuracy: 0.614800
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.0559 Validation Accuracy: 0.601000
# Epoch 12, CIFAR-10 Batch 2:  Loss:     0.9307 Validation Accuracy: 0.607200
# Epoch 12, CIFAR-10 Batch 3:  Loss:     0.8175 Validation Accuracy: 0.620000
# Epoch 12, CIFAR-10 Batch 4:  Loss:     0.8846 Validation Accuracy: 0.616200
# Epoch 12, CIFAR-10 Batch 5:  Loss:     0.8483 Validation Accuracy: 0.621600
# Epoch 13, CIFAR-10 Batch 1:  Loss:     1.0272 Validation Accuracy: 0.623200
# Epoch 13, CIFAR-10 Batch 2:  Loss:     0.8872 Validation Accuracy: 0.617000
# Epoch 13, CIFAR-10 Batch 3:  Loss:     0.8019 Validation Accuracy: 0.621200
# Epoch 13, CIFAR-10 Batch 4:  Loss:     0.8427 Validation Accuracy: 0.617600
# Epoch 13, CIFAR-10 Batch 5:  Loss:     0.8395 Validation Accuracy: 0.621600
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.9863 Validation Accuracy: 0.619400
# Epoch 14, CIFAR-10 Batch 2:  Loss:     0.8594 Validation Accuracy: 0.618600
# Epoch 14, CIFAR-10 Batch 3:  Loss:     0.8034 Validation Accuracy: 0.609200
# Epoch 14, CIFAR-10 Batch 4:  Loss:     0.8189 Validation Accuracy: 0.626200
# Epoch 14, CIFAR-10 Batch 5:  Loss:     0.8076 Validation Accuracy: 0.621400
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.9544 Validation Accuracy: 0.622200
# Epoch 15, CIFAR-10 Batch 2:  Loss:     0.8289 Validation Accuracy: 0.618000
# Epoch 15, CIFAR-10 Batch 3:  Loss:     0.7408 Validation Accuracy: 0.623800
# Epoch 15, CIFAR-10 Batch 4:  Loss:     0.8045 Validation Accuracy: 0.622600
# Epoch 15, CIFAR-10 Batch 5:  Loss:     0.7773 Validation Accuracy: 0.623200
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.9118 Validation Accuracy: 0.628000
# Epoch 16, CIFAR-10 Batch 2:  Loss:     0.7748 Validation Accuracy: 0.632400
# Epoch 16, CIFAR-10 Batch 3:  Loss:     0.7065 Validation Accuracy: 0.632200
# Epoch 16, CIFAR-10 Batch 4:  Loss:     0.8051 Validation Accuracy: 0.625000
# Epoch 16, CIFAR-10 Batch 5:  Loss:     0.7456 Validation Accuracy: 0.631800
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.8728 Validation Accuracy: 0.637800
# Epoch 17, CIFAR-10 Batch 2:  Loss:     0.7353 Validation Accuracy: 0.644000
# Epoch 17, CIFAR-10 Batch 3:  Loss:     0.6821 Validation Accuracy: 0.634800
# Epoch 17, CIFAR-10 Batch 4:  Loss:     0.7481 Validation Accuracy: 0.630200
# Epoch 17, CIFAR-10 Batch 5:  Loss:     0.7139 Validation Accuracy: 0.635200
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.8379 Validation Accuracy: 0.640800
# Epoch 18, CIFAR-10 Batch 2:  Loss:     0.7430 Validation Accuracy: 0.632400
# Epoch 18, CIFAR-10 Batch 3:  Loss:     0.6668 Validation Accuracy: 0.634000
# Epoch 18, CIFAR-10 Batch 4:  Loss:     0.7166 Validation Accuracy: 0.640600
# Epoch 18, CIFAR-10 Batch 5:  Loss:     0.7221 Validation Accuracy: 0.631200
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.8089 Validation Accuracy: 0.639400
# Epoch 19, CIFAR-10 Batch 2:  Loss:     0.6875 Validation Accuracy: 0.645400
# Epoch 19, CIFAR-10 Batch 3:  Loss:     0.6189 Validation Accuracy: 0.644400
# Epoch 19, CIFAR-10 Batch 4:  Loss:     0.7081 Validation Accuracy: 0.639400
# Epoch 19, CIFAR-10 Batch 5:  Loss:     0.7057 Validation Accuracy: 0.628200
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.7807 Validation Accuracy: 0.650000
# Epoch 20, CIFAR-10 Batch 2:  Loss:     0.6455 Validation Accuracy: 0.645200
# Epoch 20, CIFAR-10 Batch 3:  Loss:     0.6194 Validation Accuracy: 0.647600
# Epoch 20, CIFAR-10 Batch 4:  Loss:     0.6631 Validation Accuracy: 0.645200
# Epoch 20, CIFAR-10 Batch 5:  Loss:     0.6707 Validation Accuracy: 0.641800
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.7510 Validation Accuracy: 0.647200
# Epoch 21, CIFAR-10 Batch 2:  Loss:     0.6302 Validation Accuracy: 0.652000
# Epoch 21, CIFAR-10 Batch 3:  Loss:     0.5777 Validation Accuracy: 0.654800
# Epoch 21, CIFAR-10 Batch 4:  Loss:     0.6228 Validation Accuracy: 0.648400
# Epoch 21, CIFAR-10 Batch 5:  Loss:     0.6537 Validation Accuracy: 0.639400
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.7186 Validation Accuracy: 0.651600
# Epoch 22, CIFAR-10 Batch 2:  Loss:     0.6171 Validation Accuracy: 0.658600
# Epoch 22, CIFAR-10 Batch 3:  Loss:     0.5552 Validation Accuracy: 0.654000
# Epoch 22, CIFAR-10 Batch 4:  Loss:     0.6110 Validation Accuracy: 0.647000
# Epoch 22, CIFAR-10 Batch 5:  Loss:     0.6146 Validation Accuracy: 0.652600
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.6904 Validation Accuracy: 0.645200
# Epoch 23, CIFAR-10 Batch 2:  Loss:     0.6129 Validation Accuracy: 0.637800
# Epoch 23, CIFAR-10 Batch 3:  Loss:     0.5477 Validation Accuracy: 0.655400
# Epoch 23, CIFAR-10 Batch 4:  Loss:     0.5869 Validation Accuracy: 0.640600
# Epoch 23, CIFAR-10 Batch 5:  Loss:     0.5881 Validation Accuracy: 0.651200
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.6885 Validation Accuracy: 0.639200
# Epoch 24, CIFAR-10 Batch 2:  Loss:     0.6014 Validation Accuracy: 0.650600
# Epoch 24, CIFAR-10 Batch 3:  Loss:     0.5404 Validation Accuracy: 0.650400
# Epoch 24, CIFAR-10 Batch 4:  Loss:     0.5716 Validation Accuracy: 0.649800
# Epoch 24, CIFAR-10 Batch 5:  Loss:     0.5751 Validation Accuracy: 0.657200
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.7061 Validation Accuracy: 0.629200
# Epoch 25, CIFAR-10 Batch 2:  Loss:     0.5987 Validation Accuracy: 0.655000
# Epoch 25, CIFAR-10 Batch 3:  Loss:     0.5549 Validation Accuracy: 0.640000
# Epoch 25, CIFAR-10 Batch 4:  Loss:     0.5549 Validation Accuracy: 0.644400
# Epoch 25, CIFAR-10 Batch 5:  Loss:     0.5488 Validation Accuracy: 0.663600
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.6563 Validation Accuracy: 0.634600
# Epoch 26, CIFAR-10 Batch 2:  Loss:     0.5650 Validation Accuracy: 0.651000
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.5280 Validation Accuracy: 0.649800
# Epoch 26, CIFAR-10 Batch 4:  Loss:     0.5282 Validation Accuracy: 0.645600
# Epoch 26, CIFAR-10 Batch 5:  Loss:     0.5264 Validation Accuracy: 0.661000
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.6275 Validation Accuracy: 0.639000
# Epoch 27, CIFAR-10 Batch 2:  Loss:     0.5344 Validation Accuracy: 0.651600
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.5229 Validation Accuracy: 0.641000
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.5349 Validation Accuracy: 0.637200
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.5048 Validation Accuracy: 0.660400
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.6157 Validation Accuracy: 0.635800
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.4991 Validation Accuracy: 0.660600
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.4956 Validation Accuracy: 0.648600
# Epoch 28, CIFAR-10 Batch 4:  Loss:     0.5321 Validation Accuracy: 0.628200
# Epoch 28, CIFAR-10 Batch 5:  Loss:     0.4874 Validation Accuracy: 0.659400
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.5843 Validation Accuracy: 0.638000
# Epoch 29, CIFAR-10 Batch 2:  Loss:     0.4927 Validation Accuracy: 0.653400
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.4639 Validation Accuracy: 0.652400
# Epoch 29, CIFAR-10 Batch 4:  Loss:     0.5079 Validation Accuracy: 0.633000
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.4828 Validation Accuracy: 0.657400
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.5500 Validation Accuracy: 0.642000
# Epoch 30, CIFAR-10 Batch 2:  Loss:     0.4951 Validation Accuracy: 0.655000
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.4110 Validation Accuracy: 0.664200
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.4312 Validation Accuracy: 0.650400
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.4487 Validation Accuracy: 0.660600
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.5346 Validation Accuracy: 0.638000
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.4594 Validation Accuracy: 0.653200
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.4171 Validation Accuracy: 0.659800
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.4285 Validation Accuracy: 0.643800
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.4461 Validation Accuracy: 0.655400
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.4932 Validation Accuracy: 0.646200
# Epoch 32, CIFAR-10 Batch 2:  Loss:     0.4352 Validation Accuracy: 0.656000
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.3943 Validation Accuracy: 0.660200
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.4187 Validation Accuracy: 0.637600
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.4147 Validation Accuracy: 0.655400
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.4679 Validation Accuracy: 0.652200
# Epoch 33, CIFAR-10 Batch 2:  Loss:     0.4592 Validation Accuracy: 0.647200
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.3751 Validation Accuracy: 0.655600
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.3853 Validation Accuracy: 0.652000
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.3950 Validation Accuracy: 0.658800
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.4455 Validation Accuracy: 0.654000
# Epoch 34, CIFAR-10 Batch 2:  Loss:     0.4003 Validation Accuracy: 0.653800
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.3518 Validation Accuracy: 0.661200
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.3821 Validation Accuracy: 0.644600
# Epoch 34, CIFAR-10 Batch 5:  Loss:     0.3933 Validation Accuracy: 0.652200
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.4166 Validation Accuracy: 0.655000
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.3627 Validation Accuracy: 0.653000
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.3483 Validation Accuracy: 0.655400
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.3481 Validation Accuracy: 0.651000
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.3897 Validation Accuracy: 0.646200
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.4106 Validation Accuracy: 0.651600
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.3794 Validation Accuracy: 0.646000
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.3372 Validation Accuracy: 0.657400
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.3321 Validation Accuracy: 0.659200
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.3838 Validation Accuracy: 0.641600
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.3987 Validation Accuracy: 0.654400
# Epoch 37, CIFAR-10 Batch 2:  Loss:     0.3792 Validation Accuracy: 0.640800
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.3163 Validation Accuracy: 0.662600
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.3445 Validation Accuracy: 0.651000
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.3698 Validation Accuracy: 0.642000
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.3759 Validation Accuracy: 0.647200
# Epoch 38, CIFAR-10 Batch 2:  Loss:     0.3369 Validation Accuracy: 0.637800
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.2962 Validation Accuracy: 0.660800
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.3422 Validation Accuracy: 0.647000
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.3807 Validation Accuracy: 0.633800
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.4046 Validation Accuracy: 0.630200
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.3449 Validation Accuracy: 0.656000
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.3121 Validation Accuracy: 0.655600
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.3009 Validation Accuracy: 0.648400
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.3242 Validation Accuracy: 0.645800
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.3562 Validation Accuracy: 0.633400
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.3281 Validation Accuracy: 0.651000
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.2830 Validation Accuracy: 0.656400
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.2980 Validation Accuracy: 0.641800
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.3129 Validation Accuracy: 0.639600
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.3500 Validation Accuracy: 0.632200
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.3095 Validation Accuracy: 0.650600
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.2856 Validation Accuracy: 0.654800
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.2999 Validation Accuracy: 0.642800
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.2958 Validation Accuracy: 0.645600
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.3655 Validation Accuracy: 0.635600
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.3182 Validation Accuracy: 0.646000
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.2603 Validation Accuracy: 0.655800
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.3244 Validation Accuracy: 0.624000
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.2947 Validation Accuracy: 0.643400
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.3258 Validation Accuracy: 0.637200
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.2924 Validation Accuracy: 0.645000
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.2521 Validation Accuracy: 0.651400
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.2428 Validation Accuracy: 0.649400
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.2665 Validation Accuracy: 0.651600
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.3077 Validation Accuracy: 0.642600
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.2828 Validation Accuracy: 0.640600
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.2234 Validation Accuracy: 0.656000
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.2451 Validation Accuracy: 0.647600
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.2705 Validation Accuracy: 0.647800
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.3001 Validation Accuracy: 0.647200
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.2656 Validation Accuracy: 0.639400
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.2265 Validation Accuracy: 0.648000
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.2108 Validation Accuracy: 0.646000
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.2498 Validation Accuracy: 0.645200
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.3025 Validation Accuracy: 0.637000
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.2751 Validation Accuracy: 0.643000
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.2566 Validation Accuracy: 0.641800
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.2083 Validation Accuracy: 0.652600
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.2352 Validation Accuracy: 0.647600
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.2820 Validation Accuracy: 0.649800
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.2536 Validation Accuracy: 0.638000
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.2570 Validation Accuracy: 0.637800
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.2152 Validation Accuracy: 0.647400
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.2195 Validation Accuracy: 0.646400
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.2559 Validation Accuracy: 0.648800
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.2443 Validation Accuracy: 0.638600
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.2484 Validation Accuracy: 0.638600
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.1930 Validation Accuracy: 0.651600
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.2188 Validation Accuracy: 0.647000
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.2659 Validation Accuracy: 0.654400
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.2252 Validation Accuracy: 0.645800
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.2240 Validation Accuracy: 0.637600
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.1878 Validation Accuracy: 0.640800
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.2228 Validation Accuracy: 0.647000
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.2867 Validation Accuracy: 0.646000
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.2251 Validation Accuracy: 0.654200
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.1884 Validation Accuracy: 0.653000
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.1781 Validation Accuracy: 0.640400
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.2586 Validation Accuracy: 0.640800

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.643772977590561

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
